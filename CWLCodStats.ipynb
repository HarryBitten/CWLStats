# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
#pandas and numpy for wrangling the data, comment out filter warnings if not sure

# %%
df = pd.read_csv('Desktop/codStats.csv')
#change to wherever you saved it

# %%
df.sample(5)
#gives random 5 rows
# Out:
#                   match id  series id                 end time  duration (s)  \
# 1672  10799587771562727386  pro-w3-14  2019-02-22 00:51:35 UTC           948
# 189   14915917355001110776   pro-w1-6  2019-02-06 00:41:22 UTC           697
# 1422   6949897302314192854   pro-w3-8  2019-02-20 21:59:44 UTC           546
# 1844  12706562908849482030   pro-w4-4  2019-02-26 21:49:18 UTC           704
# 980   10471159275834708477  pro-w2-11  2019-02-14 20:44:09 UTC           974
#
#                   mode        map         team   player win?  score  \
# 1672  Search & Destroy    Arsenal  100 Thieves   Octane    L      5
# 189          Hardpoint   Hacienda  Reciprocity      Zed    W    250
# 1422           Control    Arsenal      Enigma6  General    W      3
# 1844  Search & Destroy  Frequency  100 Thieves  Slasher    L      2
# 980   Search & Destroy   Hacienda  Red Reserve    Bance    W      6
#
#         ...      ctrl firstdeaths  ctrl captures  2-piece  3-piece  4-piece  \
# ...

# %%
df.columns
#Lots of unneeded columns
# Out:
# Index([u'match id', u'series id', u'end time', u'duration (s)', u'mode',
#        u'map', u'team', u'player', u'win?', u'score', u'kills', u'deaths',
#        u'+/-', u'k/d', u'kills per 10min', u'deaths per 10min',
#        u'player score', u'player spm', u'ekia', u'assists', u'headshots',
#        u'suicides', u'team kills', u'team deaths', u'kills (stayed alive)',
#        u'hits', u'shots', u'accuracy (%)', u'num lives', u'time alive (s)',
#        u'avg time per life (s)', u'fave weapon', u'fave specialist',
#        u'fave scorestreaks', u'hill time (s)', u'hill captures',
#        u'hill defends', u'snd rounds', u'snd firstbloods', u'snd firstdeaths',
#        u'snd survives', u'bomb pickups', u'bomb plants', u'bomb defuses',
#        u'bomb sneak defuses', u'snd 1-kill round', u'snd 2-kill round',
#        u'snd 3-kill round', u'snd 4-kill round', u'ctrl rounds',
#        u'ctrl firstbloods', u'ctrl firstdeaths', u'ctrl captures', u'2-piece',
# ...

# %%
#so many we need to get rid of, easier to just remake the dataframe with only the columns we need
df=df[['match id','series id','end time','mode','team','win?']]
#sort by end time so its a choronological elo update
df.sort_values(by=['end time','team'], inplace=True) 
#inplace=True makes it so it permanently changes it, not just a view of the original

# %%
df.head(10)
# Out:
#                  match id series id                 end time       mode  \
# 0  missing-pro-w1-1-map-1  pro-w1-1  2019-02-04 18:22:38 UTC  Hardpoint
# 1  missing-pro-w1-1-map-1  pro-w1-1  2019-02-04 18:22:38 UTC  Hardpoint
# 2  missing-pro-w1-1-map-1  pro-w1-1  2019-02-04 18:22:38 UTC  Hardpoint
# 3  missing-pro-w1-1-map-1  pro-w1-1  2019-02-04 18:22:38 UTC  Hardpoint
# 4  missing-pro-w1-1-map-1  pro-w1-1  2019-02-04 18:22:38 UTC  Hardpoint
# 5  missing-pro-w1-1-map-1  pro-w1-1  2019-02-04 18:22:38 UTC  Hardpoint
# 6  missing-pro-w1-1-map-1  pro-w1-1  2019-02-04 18:22:38 UTC  Hardpoint
# 7  missing-pro-w1-1-map-1  pro-w1-1  2019-02-04 18:22:38 UTC  Hardpoint
# 8  missing-pro-w1-1-map-1  pro-w1-1  2019-02-04 18:22:38 UTC  Hardpoint
# 9  missing-pro-w1-1-map-1  pro-w1-1  2019-02-04 18:22:38 UTC  Hardpoint
#
#           team win?
# 0  Reciprocity    L
# 1  Reciprocity    L
# 2  Reciprocity    L
# 3  Reciprocity    L
# 4  Reciprocity    L
# 5  Red Reserve    W
# 6  Red Reserve    W
# ...

# %%
#need to make rows unique because we have 10 rows for each map (10 players) instead of 2 (2 teams)
df2 = df[df.index % 5 == 0]
#just select every 5th row for team starting from 0, will be fine as we sorted by start/end time

# %%
df2.head(10)
# Out:
#                   match id series id                 end time  \
# 0   missing-pro-w1-1-map-1  pro-w1-1  2019-02-04 18:22:38 UTC
# 5   missing-pro-w1-1-map-1  pro-w1-1  2019-02-04 18:22:38 UTC
# 10    11649379009951618401  pro-w1-1  2019-02-04 23:34:44 UTC
# 15    11649379009951618401  pro-w1-1  2019-02-04 23:34:44 UTC
# 20     6748785192811752982  pro-w1-1  2019-02-04 23:58:08 UTC
# 25     6748785192811752982  pro-w1-1  2019-02-04 23:58:08 UTC
# 30     1109825659259196104  pro-w1-2  2019-02-05 00:35:37 UTC
# 35     1109825659259196104  pro-w1-2  2019-02-05 00:35:37 UTC
# 40    10378398561043327872  pro-w1-2  2019-02-05 00:52:01 UTC
# 45    10378398561043327872  pro-w1-2  2019-02-05 00:52:01 UTC
#
#                 mode          team win?
# 0          Hardpoint   Reciprocity    L
# 5          Hardpoint   Red Reserve    W
# 10  Search & Destroy   Reciprocity    L
# 15  Search & Destroy   Red Reserve    W
# 20           Control   Reciprocity    L
# ...

# %%
df = pd.read_csv('Desktop/Test.csv') #reloading the excel file that I changed and saved to different name

# %%
df.head(10)
#Can see I added team1 team2 winningTeam losingTeam,
#NEED TO SIMPLIFY THIS BIT - VERY INNEFFICIENT
#Now need to delete every second row b/c the way I did it was really wierd and every 2nd row is nonsense
# Out:
#                  match id series id                 end time  \
# 0  missing-pro-w1-1-map-1  pro-w1-1  2019-02-04 18:22:38 UTC
# 1  missing-pro-w1-1-map-1  pro-w1-1  2019-02-04 18:22:38 UTC
# 2    11649379009951600000  pro-w1-1  2019-02-04 23:34:44 UTC
# 3    11649379009951600000  pro-w1-1  2019-02-04 23:34:44 UTC
# 4     6748785192811750000  pro-w1-1  2019-02-04 23:58:08 UTC
# 5     6748785192811750000  pro-w1-1  2019-02-04 23:58:08 UTC
# 6     1109825659259190000  pro-w1-2  2019-02-05 00:35:37 UTC
# 7     1109825659259190000  pro-w1-2  2019-02-05 00:35:37 UTC
# 8    10378398561043300000  pro-w1-2  2019-02-05 00:52:01 UTC
# 9    10378398561043300000  pro-w1-2  2019-02-05 00:52:01 UTC
#
#                mode         team1 win?         team2  winningTeam  \
# 0         Hardpoint   Reciprocity    L   Red Reserve  Red Reserve
# 1         Hardpoint   Red Reserve    W   Reciprocity  Red Reserve
# 2  Search & Destroy   Reciprocity    L   Red Reserve  Red Reserve
# ...

# %%
df2 = df[df.index % 2 == 0]
#df2.head(25)

# %%
#I think its in the right kind of format now to create ELO

# %%
df2.team1.unique()
# Out:
# array(['Reciprocity', 'Midnight', 'Evil Geniuses', 'Gen.G',
#        'OpTic Gaming', 'Luminosity', 'Red Reserve', 'Heretics', 'Denial',
#        'ExcelerateGG', 'Enigma6', '100 Thieves', 'Splyce', 'Excelerate',
#        'Team Envy'], dtype=object)

# %%
df2.team2.unique()
# Out:
# array(['Red Reserve', 'OpTic Gaming', 'Midnight', 'UYU', 'Reciprocity',
#        'Gen.G', 'Luminosity', 'eUnited', 'Enigma6', 'Heretics',
#        'Team Envy', 'Splyce', 'Denial', 'Excelerate'], dtype=object)

# %%
global thievesHPElo
global redHPElo
global opticHPElo
global midnightHPElo
global uyuHPElo
global recHPElo
global gengHPElo
global luminHPElo
global eunitedHPElo
global e6HPElo
global hereticsHPElo
global nvHPElo
global splyceHPElo
global denialHPElo
global excelHPElo
global egHPElo

global thievesSNDElo
global redSNDElo
global opticSNDElo
global midnightSNDElo
global uyuSNDElo
global recSNDElo
global gengSNDElo
global luminSNDElo
global eunitedSNDElo
global e6SNDElo
global hereticsSNDElo
global nvSNDElo
global splyceSNDElo
global denialSNDElo
global excelSNDElo
global egSNDElo

global thievesCNTRLElo
global redCNTRLElo
global opticCNTRLElo
global midnightCNTRLElo
global uyuCNTRLElo
global recCNTRLElo
global gengCNTRLElo
global luminCNTRLElo
global eunitedCNTRLElo
global e6CNTRLElo
global hereticsCNTRLElo
global nvCNTRLElo
global splyceCNTRLElo
global denialCNTRLElo
global excelCNTRLElo
global egCNTRLElo

egHPElo = 1200
excelHPElo = 1200
denialHPElo = 1200
splyceHPElo = 1200
nvHPElo = 1200
hereticsHPElo = 1200
e6HPElo = 1200
eunitedHPElo = 1200
luminHPElo = 1200
gengHPElo = 1200
recHPElo = 1200
uyuHPElo = 1200
midnightHPElo = 1200
opticHPElo = 1200
redHPElo = 1200
thievesHPElo = 1200

thievesSNDElo = 1200
redSNDElo = 1200
opticSNDElo = 1200
midnightSNDElo = 1200
uyuSNDElo = 1200
recSNDElo = 1200
gengSNDElo = 1200
luminSNDElo = 1200
eunitedSNDElo = 1200
e6SNDElo = 1200
hereticsSNDElo = 1200
nvSNDElo = 1200
splyceSNDElo = 1200
denialSNDElo = 1200
excelSNDElo = 1200
egSNDElo = 1200

thievesCNTRLElo = 1200
redCNTRLElo = 1200
opticCNTRLElo = 1200
midnightCNTRLElo = 1200
uyuCNTRLElo = 1200
recCNTRLElo = 1200
gengCNTRLElo = 1200
luminCNTRLElo = 1200
eunitedCNTRLElo = 1200
e6CNTRLElo = 1200
hereticsCNTRLElo = 1200
nvCNTRLElo = 1200
splyceCNTRLElo = 1200
denialCNTRLElo = 1200
excelCNTRLElo = 1200
egCNTRLElo = 1200

# %%
df2.set_index("mode",inplace=True)
dfHP = df2.loc[['Hardpoint']]

# %%
dfHP.reset_index()
# Out:
#          mode                 match id  series id                 end time  \
# 0   Hardpoint   missing-pro-w1-1-map-1   pro-w1-1  2019-02-04 18:22:38 UTC
# 1   Hardpoint      1109825659259190000   pro-w1-2  2019-02-05 00:35:37 UTC
# 2   Hardpoint   missing-pro-w1-4-map-1   pro-w1-4  2019-02-05 17:01:38 UTC
# 3   Hardpoint      6429151219053430000   pro-w1-3  2019-02-05 20:18:47 UTC
# 4   Hardpoint     10597424156478500000   pro-w1-3  2019-02-05 21:09:41 UTC
# 5   Hardpoint     16382739382043200000   pro-w1-5  2019-02-05 22:56:01 UTC
# 6   Hardpoint     17290758994063800000   pro-w1-5  2019-02-05 23:51:54 UTC
# 7   Hardpoint     14915917355001100000   pro-w1-6  2019-02-06 00:41:22 UTC
# 8   Hardpoint     16593989433782300000   pro-w1-6  2019-02-06 01:39:49 UTC
# 9   Hardpoint      6661981621374780000   pro-w1-7  2019-02-06 20:19:49 UTC
# 10  Hardpoint       876448039511825000   pro-w1-7  2019-02-06 21:11:53 UTC
# ...

# %%
dfSND = df2.loc[["Search & Destroy"]]
dfSND.reset_index()
#dfSND
# Out:
#                 mode                 match id  series id  \
# 0   Search & Destroy     11649379009951600000   pro-w1-1
# 1   Search & Destroy     10378398561043300000   pro-w1-2
# 2   Search & Destroy      1443184693623220000   pro-w1-3
# 3   Search & Destroy       621889796890011000   pro-w1-4
# 4   Search & Destroy     14889547872935100000   pro-w1-5
# 5   Search & Destroy      1551849084828110000   pro-w1-5
# 6   Search & Destroy      7767666358085150000   pro-w1-6
# 7   Search & Destroy     12892240013875200000   pro-w1-6
# 8   Search & Destroy      5580091459027850000   pro-w1-7
# 9   Search & Destroy      8479139306551340000   pro-w1-8
# 10  Search & Destroy     16600597112602700000   pro-w1-9
# 11  Search & Destroy      9786059639033020000   pro-w1-9
# 12  Search & Destroy      9755592170701560000  pro-w1-10
# 13  Search & Destroy      1863823143887000000  pro-w1-11
# 14  Search & Destroy     12699638050821100000  pro-w1-12
# ...

# %%
dfCNTRL = df2.loc[["Control"]]
dfCNTRL.reset_index()
#dfCNTRL
# Out:
#        mode              match id  series id                 end time  \
# 0   Control   6748785192811750000   pro-w1-1  2019-02-04 23:58:08 UTC
# 1   Control  18254650928422600000   pro-w1-2  2019-02-05 01:06:36 UTC
# 2   Control  17309257835923800000   pro-w1-3  2019-02-05 20:56:52 UTC
# 3   Control  17534793650061700000   pro-w1-4  2019-02-05 22:17:34 UTC
# 4   Control    563572596410693000   pro-w1-5  2019-02-05 23:38:40 UTC
# 5   Control  12858572640367200000   pro-w1-6  2019-02-06 01:24:03 UTC
# 6   Control   5269668258822650000   pro-w1-7  2019-02-06 20:57:18 UTC
# 7   Control   2002423450755060000   pro-w1-8  2019-02-06 22:20:36 UTC
# 8   Control   4082798738615510000   pro-w1-9  2019-02-06 23:46:03 UTC
# 9   Control  13055982141822300000  pro-w1-10  2019-02-07 01:32:14 UTC
# 10  Control   4830307393054430000  pro-w1-11  2019-02-07 20:54:01 UTC
# 11  Control   8551374396209720000  pro-w1-12  2019-02-07 22:06:44 UTC
# ...

# %%
import math 
  
# Function to calculate the Probability 
def Probability(rating1, rating2): 
  
    return 1.0 * 1.0 / (1 + 1.0 * math.pow(10, 1.0 * (rating1 - rating2) / 400)) 
  
  
# Function to calculate Elo rating 
# K is a constant. 
# d determines whether 
# Team A wins or Player B.  
def EloRating(Rwinteam, Rloseteam): 

    K=40
    d=1
    # To calculate the Winning 
    # Probability of Team B 
    Pb = Probability(Rwinteam, Rloseteam) 
  
    # To calculate the Winning 
    # Probability of Team A 
    Pa = Probability(Rloseteam, Rwinteam) 
  
    # Case -1 When Team A wins 
    # Updating the Elo Ratings 
    if (d == 1) : 
        Rwinteam = Rwinteam + K * (1 - Pa) 
        Rloseteam = Rloseteam + K * (0 - Pb) 
      
  
    # Case -2 When Team B wins 
    # Updating the Elo Ratings 
    else : 
        Rwinteam = Rloseteam + K * (0 - Pa) 
        Rwinteam = Rloseteam + K * (1 - Pb) 
      
  
    #print("Updated Ratings:-") 
    #print("Rwinteam =", round(Rwinteam, 6)," Rloseteam =", round(Rloseteam, 6)) 
    #print Rwinteam
    #print Rloseteam
    return Rwinteam, Rloseteam

# %%
#Need to change how this is done because this is spaghetti
for index, row in dfHP.iterrows():
    if (row['winningTeam'] == 'Enigma6'):
        Rwinteam = e6HPElo
    elif (row['winningTeam'] == 'Splyce'):
        Rwinteam = splyceHPElo
    elif (row['winningTeam'] == '100 Thieves'):
        Rwinteam = thievesHPElo
    elif (row['winningTeam'] == 'Team Envy'):
        Rwinteam = nvHPElo
    elif (row['winningTeam'] == 'Heretics'):
        Rwinteam = hereticsHPElo
    elif (row['winningTeam'] == 'eUnited'):
        Rwinteam = eunitedHPElo
    elif (row['winningTeam'] == 'Denial'):
        Rwinteam = denialHPElo
    elif (row['winningTeam'] == 'Midnight'):
        Rwinteam = midnightHPElo
    elif (row['winningTeam'] == 'Gen.G'):
        Rwinteam = gengHPElo
    elif (row['winningTeam'] == 'UYU'):
        Rwinteam = uyuHPElo
    elif (row['winningTeam'] == 'Reciprocity'):
        Rwinteam = recHPElo
    elif (row['winningTeam'] == 'Evil Geniuses'):
        Rwinteam = egHPElo
    elif (row['winningTeam'] == 'OpTic Gaming'):
        Rwinteam = opticHPElo
    elif (row['winningTeam'] == 'Luminosity'):
        Rwinteam = luminHPElo
    elif (row['winningTeam'] == 'Red Reserve'):
        Rwinteam = redHPElo
    else:
        Rwinteam = excelHPElo

    if (row['losingTeam'] == 'Enigma6'):
        Rloseteam = e6HPElo
    elif (row['losingTeam'] == 'Splyce'):
        Rloseteam = splyceHPElo
    elif (row['losingTeam'] == '100 Thieves'):
        Rloseteam = thievesHPElo
    elif (row['losingTeam'] == 'Team Envy'):
        Rloseteam = nvHPElo
    elif (row['losingTeam'] == 'Heretics'):
        Rloseteam = hereticsHPElo
    elif (row['losingTeam'] == 'eUnited'):
        Rloseteam = eunitedHPElo
    elif (row['losingTeam'] == 'Denial'):
        Rloseteam = denialHPElo
    elif (row['losingTeam'] == 'Midnight'):
        Rloseteam = midnightHPElo
    elif (row['losingTeam'] == 'Gen.G'):
        Rloseteam = gengHPElo
    elif (row['losingTeam'] == 'UYU'):
        Rloseteam = uyuHPElo
    elif (row['losingTeam'] == 'Reciprocity'):
        Rloseteam = recHPElo
    elif (row['losingTeam'] == 'Evil Geniuses'):
        Rloseteam = egHPElo
    elif (row['losingTeam'] == 'OpTic Gaming'):
        Rloseteam = opticHPElo
    elif (row['losingTeam'] == 'Luminosity'):
        Rloseteam = luminHPElo
    elif (row['losingTeam'] == 'Red Reserve'):
        Rloseteam = redHPElo
    else:
        Rloseteam = excelHPElo
        
    Rwinteam, Rloseteam = EloRating(Rwinteam, Rloseteam)
    #print Rwinteam, Rloseteam
    #Rwinteam, Rloseteam = EloRating(Rwinteam, Rloseteam) 
    
    if (row['winningTeam'] == 'Enigma6'):
        e6HPElo = Rwinteam
    elif (row['winningTeam'] == 'Splyce'):
        splyceHPElo = Rwinteam
    elif (row['winningTeam'] == '100 Thieves'):
        thievesHPElo = Rwinteam
    elif (row['winningTeam'] == 'Team Envy'):
        nvHPElo = Rwinteam 
    elif (row['winningTeam'] == 'Heretics'):
        hereticsHPElo = Rwinteam 
    elif (row['winningTeam'] == 'eUnited'):
        eunitedHPElo = Rwinteam 
    elif (row['winningTeam'] == 'Denial'):
        denialHPElo = Rwinteam
    elif (row['winningTeam'] == 'Midnight'):
        midnightHPElo = Rwinteam
    elif (row['winningTeam'] == 'Gen.G'):
        gengHPElo = Rwinteam
    elif (row['winningTeam'] == 'UYU'):
        uyuHPElo = Rwinteam
    elif (row['winningTeam'] == 'Reciprocity'):
        recHPElo = Rwinteam
    elif (row['winningTeam'] == 'Evil Geniuses'):
        egHPElo = Rwinteam
    elif (row['winningTeam'] == 'OpTic Gaming'):
        opticHPElo = Rwinteam
    elif (row['winningTeam'] == 'Luminosity'):
        luminHPElo = Rwinteam 
    elif (row['winningTeam'] == 'Red Reserve'):
        redHPElo = Rwinteam
    else:
        excelHPElo = Rwinteam

    if (row['losingTeam'] == 'Enigma6'):
        e6HPElo = Rloseteam 
    elif (row['losingTeam'] == 'Splyce'):
        splyceHPElo = Rloseteam 
    elif (row['losingTeam'] == '100 Thieves'):
        thievesHPElo = Rloseteam 
    elif (row['losingTeam'] == 'Team Envy'):
        nvHPElo = Rloseteam
    elif (row['losingTeam'] == 'Heretics'):
        hereticsHPElo = Rloseteam 
    elif (row['losingTeam'] == 'eUnited'):
        eunitedHPElo = Rloseteam
    elif (row['losingTeam'] == 'Denial'):
        denialHPElo = Rloseteam
    elif (row['losingTeam'] == 'Midnight'):
        midnightHPElo = Rloseteam
    elif (row['losingTeam'] == 'Gen.G'):
        gengHPElo = Rloseteam 
    elif (row['losingTeam'] == 'UYU'):
        uyuHPElo = Rloseteam
    elif (row['losingTeam'] == 'Reciprocity'):
        recHPElo = Rloseteam
    elif (row['losingTeam'] == 'Evil Geniuses'):
        egHPElo = Rloseteam
    elif (row['losingTeam'] == 'OpTic Gaming'):
        opticHPElo = Rloseteam
    elif (row['losingTeam'] == 'Luminosity'):
        luminHPElo = Rloseteam
    elif (row['losingTeam'] == 'Red Reserve'):
        redHPElo = Rloseteam
    else:
        excelHPElo = Rloseteam

# %%
for index, row in dfSND.iterrows():
    if (row['winningTeam'] == 'Enigma6'):
        Rwinteam = e6SNDElo
    elif (row['winningTeam'] == 'Splyce'):
        Rwinteam = splyceSNDElo
    elif (row['winningTeam'] == '100 Thieves'):
        Rwinteam = thievesSNDElo
    elif (row['winningTeam'] == 'Team Envy'):
        Rwinteam = nvSNDElo
    elif (row['winningTeam'] == 'Heretics'):
        Rwinteam = hereticsSNDElo
    elif (row['winningTeam'] == 'eUnited'):
        Rwinteam = eunitedSNDElo
    elif (row['winningTeam'] == 'Denial'):
        Rwinteam = denialSNDElo
    elif (row['winningTeam'] == 'Midnight'):
        Rwinteam = midnightSNDElo
    elif (row['winningTeam'] == 'Gen.G'):
        Rwinteam = gengSNDElo
    elif (row['winningTeam'] == 'UYU'):
        Rwinteam = uyuSNDElo
    elif (row['winningTeam'] == 'Reciprocity'):
        Rwinteam = recSNDElo
    elif (row['winningTeam'] == 'Evil Geniuses'):
        Rwinteam = egSNDElo
    elif (row['winningTeam'] == 'OpTic Gaming'):
        Rwinteam = opticSNDElo
    elif (row['winningTeam'] == 'Luminosity'):
        Rwinteam = luminSNDElo
    elif (row['winningTeam'] == 'Red Reserve'):
        Rwinteam = redSNDElo
    else:
        Rwinteam = excelSNDElo

    if (row['losingTeam'] == 'Enigma6'):
        Rloseteam = e6SNDElo
    elif (row['losingTeam'] == 'Splyce'):
        Rloseteam = splyceSNDElo
    elif (row['losingTeam'] == '100 Thieves'):
        Rloseteam = thievesSNDElo
    elif (row['losingTeam'] == 'Team Envy'):
        Rloseteam = nvSNDElo
    elif (row['losingTeam'] == 'Heretics'):
        Rloseteam = hereticsSNDElo
    elif (row['losingTeam'] == 'eUnited'):
        Rloseteam = eunitedSNDElo
    elif (row['losingTeam'] == 'Denial'):
        Rloseteam = denialSNDElo
    elif (row['losingTeam'] == 'Midnight'):
        Rloseteam = midnightSNDElo
    elif (row['losingTeam'] == 'Gen.G'):
        Rloseteam = gengSNDElo
    elif (row['losingTeam'] == 'UYU'):
        Rloseteam = uyuSNDElo
    elif (row['losingTeam'] == 'Reciprocity'):
        Rloseteam = recSNDElo
    elif (row['losingTeam'] == 'Evil Geniuses'):
        Rloseteam = egSNDElo
    elif (row['losingTeam'] == 'OpTic Gaming'):
        Rloseteam = opticSNDElo
    elif (row['losingTeam'] == 'Luminosity'):
        Rloseteam = luminSNDElo
    elif (row['losingTeam'] == 'Red Reserve'):
        Rloseteam = redSNDElo
    else:
        Rloseteam = excelSNDElo
        
    Rwinteam, Rloseteam = EloRating(Rwinteam, Rloseteam)
    #print Rwinteam, Rloseteam
    #Rwinteam, Rloseteam = EloRating(Rwinteam, Rloseteam) 
    
    if (row['winningTeam'] == 'Enigma6'):
        e6SNDElo = Rwinteam
    elif (row['winningTeam'] == 'Splyce'):
        splyceSNDElo = Rwinteam
    elif (row['winningTeam'] == '100 Thieves'):
        thievesSNDElo = Rwinteam
    elif (row['winningTeam'] == 'Team Envy'):
        nvSNDElo = Rwinteam 
    elif (row['winningTeam'] == 'Heretics'):
        hereticsSNDElo = Rwinteam 
    elif (row['winningTeam'] == 'eUnited'):
        eunitedSNDElo = Rwinteam 
    elif (row['winningTeam'] == 'Denial'):
        denialSNDElo = Rwinteam
    elif (row['winningTeam'] == 'Midnight'):
        midnightSNDElo = Rwinteam
    elif (row['winningTeam'] == 'Gen.G'):
        gengSNDElo = Rwinteam
    elif (row['winningTeam'] == 'UYU'):
        uyuSNDElo = Rwinteam
    elif (row['winningTeam'] == 'Reciprocity'):
        recSNDElo = Rwinteam
    elif (row['winningTeam'] == 'Evil Geniuses'):
        egSNDElo = Rwinteam
    elif (row['winningTeam'] == 'OpTic Gaming'):
        opticSNDElo = Rwinteam
    elif (row['winningTeam'] == 'Luminosity'):
        luminSNDElo = Rwinteam 
    elif (row['winningTeam'] == 'Red Reserve'):
        redSNDElo = Rwinteam
    else:
        excelSNDElo = Rwinteam

    if (row['losingTeam'] == 'Enigma6'):
        e6SNDElo = Rloseteam 
    elif (row['losingTeam'] == 'Splyce'):
        splyceSNDElo = Rloseteam 
    elif (row['losingTeam'] == '100 Thieves'):
        thievesSNDElo = Rloseteam 
    elif (row['losingTeam'] == 'Team Envy'):
        nvSNDElo = Rloseteam
    elif (row['losingTeam'] == 'Heretics'):
        hereticsSNDElo = Rloseteam 
    elif (row['losingTeam'] == 'eUnited'):
        eunitedSNDElo = Rloseteam
    elif (row['losingTeam'] == 'Denial'):
        denialSNDElo = Rloseteam
    elif (row['losingTeam'] == 'Midnight'):
        midnightSNDElo = Rloseteam
    elif (row['losingTeam'] == 'Gen.G'):
        gengSNDElo = Rloseteam 
    elif (row['losingTeam'] == 'UYU'):
        uyuSNDElo = Rloseteam
    elif (row['losingTeam'] == 'Reciprocity'):
        recSNDElo = Rloseteam
    elif (row['losingTeam'] == 'Evil Geniuses'):
        egSNDElo = Rloseteam
    elif (row['losingTeam'] == 'OpTic Gaming'):
        opticSNDElo = Rloseteam
    elif (row['losingTeam'] == 'Luminosity'):
        luminSNDElo = Rloseteam
    elif (row['losingTeam'] == 'Red Reserve'):
        redSNDElo = Rloseteam
    else:
        excelSNDElo = Rloseteam

# %%
for index, row in dfCNTRL.iterrows():
    if (row['winningTeam'] == 'Enigma6'):
        Rwinteam = e6CNTRLElo
    elif (row['winningTeam'] == 'Splyce'):
        Rwinteam = splyceCNTRLElo
    elif (row['winningTeam'] == '100 Thieves'):
        Rwinteam = thievesCNTRLElo
    elif (row['winningTeam'] == 'Team Envy'):
        Rwinteam = nvCNTRLElo
    elif (row['winningTeam'] == 'Heretics'):
        Rwinteam = hereticsCNTRLElo
    elif (row['winningTeam'] == 'eUnited'):
        Rwinteam = eunitedCNTRLElo
    elif (row['winningTeam'] == 'Denial'):
        Rwinteam = denialCNTRLElo
    elif (row['winningTeam'] == 'Midnight'):
        Rwinteam = midnightCNTRLElo
    elif (row['winningTeam'] == 'Gen.G'):
        Rwinteam = gengCNTRLElo
    elif (row['winningTeam'] == 'UYU'):
        Rwinteam = uyuCNTRLElo
    elif (row['winningTeam'] == 'Reciprocity'):
        Rwinteam = recCNTRLElo
    elif (row['winningTeam'] == 'Evil Geniuses'):
        Rwinteam = egCNTRLElo
    elif (row['winningTeam'] == 'OpTic Gaming'):
        Rwinteam = opticCNTRLElo
    elif (row['winningTeam'] == 'Luminosity'):
        Rwinteam = luminCNTRLElo
    elif (row['winningTeam'] == 'Red Reserve'):
        Rwinteam = redCNTRLElo
    else:
        Rwinteam = excelCNTRLElo

    if (row['losingTeam'] == 'Enigma6'):
        Rloseteam = e6CNTRLElo
    elif (row['losingTeam'] == 'Splyce'):
        Rloseteam = splyceCNTRLElo
    elif (row['losingTeam'] == '100 Thieves'):
        Rloseteam = thievesCNTRLElo
    elif (row['losingTeam'] == 'Team Envy'):
        Rloseteam = nvCNTRLElo
    elif (row['losingTeam'] == 'Heretics'):
        Rloseteam = hereticsCNTRLElo
    elif (row['losingTeam'] == 'eUnited'):
        Rloseteam = eunitedCNTRLElo
    elif (row['losingTeam'] == 'Denial'):
        Rloseteam = denialCNTRLElo
    elif (row['losingTeam'] == 'Midnight'):
        Rloseteam = midnightCNTRLElo
    elif (row['losingTeam'] == 'Gen.G'):
        Rloseteam = gengCNTRLElo
    elif (row['losingTeam'] == 'UYU'):
        Rloseteam = uyuCNTRLElo
    elif (row['losingTeam'] == 'Reciprocity'):
        Rloseteam = recCNTRLElo
    elif (row['losingTeam'] == 'Evil Geniuses'):
        Rloseteam = egCNTRLElo
    elif (row['losingTeam'] == 'OpTic Gaming'):
        Rloseteam = opticHPElo
    elif (row['losingTeam'] == 'Luminosity'):
        Rloseteam = luminCNTRLElo
    elif (row['losingTeam'] == 'Red Reserve'):
        Rloseteam = redCNTRLElo
    else:
        Rloseteam = excelCNTRLElo
        
    Rwinteam, Rloseteam = EloRating(Rwinteam, Rloseteam)
    #print Rwinteam, Rloseteam
    #Rwinteam, Rloseteam = EloRating(Rwinteam, Rloseteam) 
    
    if (row['winningTeam'] == 'Enigma6'):
        e6CNTRLElo = Rwinteam
    elif (row['winningTeam'] == 'Splyce'):
        splyceCNTRLElo = Rwinteam
    elif (row['winningTeam'] == '100 Thieves'):
        thievesCNTRLElo = Rwinteam
    elif (row['winningTeam'] == 'Team Envy'):
        nvCNTRLElo = Rwinteam 
    elif (row['winningTeam'] == 'Heretics'):
        hereticsCNTRLElo = Rwinteam 
    elif (row['winningTeam'] == 'eUnited'):
        eunitedCNTRLElo = Rwinteam 
    elif (row['winningTeam'] == 'Denial'):
        denialCNTRLElo = Rwinteam
    elif (row['winningTeam'] == 'Midnight'):
        midnightCNTRLElo = Rwinteam
    elif (row['winningTeam'] == 'Gen.G'):
        gengCNTRLElo = Rwinteam
    elif (row['winningTeam'] == 'UYU'):
        uyuCNTRLElo = Rwinteam
    elif (row['winningTeam'] == 'Reciprocity'):
        recCNTRLElo = Rwinteam
    elif (row['winningTeam'] == 'Evil Geniuses'):
        egCNTRLElo = Rwinteam
    elif (row['winningTeam'] == 'OpTic Gaming'):
        opticCNTRLElo = Rwinteam
    elif (row['winningTeam'] == 'Luminosity'):
        luminCNTRLElo = Rwinteam 
    elif (row['winningTeam'] == 'Red Reserve'):
        redCNTRLElo = Rwinteam
    else:
        excelCNTRLElo = Rwinteam

    if (row['losingTeam'] == 'Enigma6'):
        e6CNTRLElo = Rloseteam 
    elif (row['losingTeam'] == 'Splyce'):
        splyceCNTRLElo = Rloseteam 
    elif (row['losingTeam'] == '100 Thieves'):
        thievesCNTRLElo = Rloseteam 
    elif (row['losingTeam'] == 'Team Envy'):
        nvCNTRLElo = Rloseteam
    elif (row['losingTeam'] == 'Heretics'):
        hereticsCNTRLElo = Rloseteam 
    elif (row['losingTeam'] == 'eUnited'):
        eunitedCNTRLElo = Rloseteam
    elif (row['losingTeam'] == 'Denial'):
        denialCNTRLElo = Rloseteam
    elif (row['losingTeam'] == 'Midnight'):
        midnightCNTRLElo = Rloseteam
    elif (row['losingTeam'] == 'Gen.G'):
        gengCNTRLElo = Rloseteam 
    elif (row['losingTeam'] == 'UYU'):
        uyuCNTRLElo = Rloseteam
    elif (row['losingTeam'] == 'Reciprocity'):
        recCNTRLElo = Rloseteam
    elif (row['losingTeam'] == 'Evil Geniuses'):
        egCNTRLElo = Rloseteam
    elif (row['losingTeam'] == 'OpTic Gaming'):
        opticCNTRLElo = Rloseteam
    elif (row['losingTeam'] == 'Luminosity'):
        luminCNTRLElo = Rloseteam
    elif (row['losingTeam'] == 'Red Reserve'):
        redCNTRLElo = Rloseteam
    else:
        excelCNTRLElo = Rloseteam

# %%
def printelos():
    print ('HP \n')
    print '100T HP Elo: ' + str(thievesHPElo)
    print 'RR HP Elo: ' + str(redHPElo)
    print 'Optic HP Elo: ' + str(opticHPElo)
    print 'Midnight HP Elo: ' + str(midnightHPElo)
    print 'UYU HP Elo: ' + str(uyuHPElo)
    print 'REC HP Elo: ' + str(recHPElo)
    print 'GEN.G HP Elo: ' + str(gengHPElo)
    print 'LG HP Elo: ' + str(luminHPElo)
    print 'eU HP Elo: ' + str(eunitedHPElo)
    print 'E6 HP Elo: ' + str(e6HPElo)
    print 'Heretics HP Elo: ' + str(hereticsHPElo)
    print 'nv HP Elo: ' + str(nvHPElo)
    print 'Splyce HP Elo: ' + str(splyceHPElo)
    print 'Denial HP Elo: ' +str(denialHPElo)
    print 'Excel HP Elo: ' + str(excelHPElo)
    print 'EG HP Elo: ' + str(egHPElo)
    print ('\n')

    print ('SND \n')
    print '100T SND Elo: ' + str(thievesSNDElo)
    print 'RR SND Elo: ' + str(redSNDElo)
    print 'Optic SND Elo: ' + str(opticSNDElo)
    print 'Midnight SND Elo: ' + str(midnightSNDElo)
    print 'UYU SND Elo: ' + str(uyuSNDElo)
    print 'REC SND Elo: ' + str(recSNDElo)
    print 'GEN.G SND Elo: ' + str(gengSNDElo)
    print 'LG SND Elo: ' + str(luminSNDElo)
    print 'eU SND Elo: ' + str(eunitedSNDElo)
    print 'E6 SND Elo: ' + str(e6SNDElo)
    print 'Heretics SND Elo: ' + str(hereticsSNDElo)
    print 'nv SND Elo: ' + str(nvSNDElo)
    print 'Splyce SND Elo: ' + str(splyceSNDElo)
    print 'Denial SND Elo: ' +str(denialSNDElo)
    print 'Excel SND Elo: ' + str(excelSNDElo)
    print 'EG SND Elo: ' + str(egSNDElo)
    print ('\n')

    print ('Control \n')
    print '100T CNTRL Elo: ' + str(thievesCNTRLElo)
    print 'RR CNTRL Elo: ' + str(redCNTRLElo)
    print 'Optic CNTRL Elo: ' + str(opticCNTRLElo)
    print 'Midnight CNTRL Elo: ' + str(midnightCNTRLElo)
    print 'UYU CNTRL Elo: ' + str(uyuCNTRLElo)
    print 'REC CNTRL Elo: ' + str(recCNTRLElo)
    print 'GEN.G CNTRL Elo: ' + str(gengCNTRLElo)
    print 'LG CNTRL Elo: ' + str(luminCNTRLElo)
    print 'eU CNTRL Elo: ' + str(eunitedCNTRLElo)
    print 'E6 CNTRL Elo: ' + str(e6CNTRLElo)
    print 'Heretics CNTRL Elo: ' + str(hereticsCNTRLElo)
    print 'nv CNTRL Elo: ' + str(nvCNTRLElo)
    print 'Splyce CNTRL Elo: ' + str(splyceCNTRLElo)
    print 'Denial CNTRL Elo: ' +str(denialCNTRLElo)
    print 'Excel CNTRL Elo: ' + str(excelCNTRLElo)
    print 'EG CNTRL Elo: ' + str(egCNTRLElo)

# %%
# Function to calculate the Probability 
def winChance(team1, team2): 
  
    return 'chance of team 2 to win: '+  str(1.0 * 1.0 / (1 + 1.0 * math.pow(10, 1.0 * (team1 - team2) / 400)))

# %%
import operator

def showUpdatedElos():
        controlElos = {'thieves': thievesCNTRLElo, 'red':redCNTRLElo, 'optic':opticCNTRLElo, 'midnight':midnightCNTRLElo, 'uyu':uyuCNTRLElo, 'rec':recCNTRLElo, 'gen g':gengCNTRLElo, 'lg':luminCNTRLElo, 'eunited':eunitedCNTRLElo, 'e6':e6CNTRLElo, 'heretics':hereticsCNTRLElo, 'nv':nvCNTRLElo, 'splyce':splyceCNTRLElo, 'denial':denialCNTRLElo, 'excel':excelCNTRLElo, 'eg':egCNTRLElo}
        hpElos = {'thieves':thievesHPElo, 'red':redHPElo, 'optic':opticHPElo,'midnight':midnightHPElo, 'uyu':uyuHPElo, 'rec':recHPElo, 'gen g':gengHPElo, 'lg':luminHPElo, 'eunited':eunitedHPElo, 'e6':e6HPElo, 'heretics':hereticsHPElo, 'nv':nvHPElo, 'splyce':splyceHPElo, 'denial':denialHPElo, 'excel':excelHPElo, 'eg':egHPElo}
        sndElos = {'thieves':thievesSNDElo, 'red':redSNDElo, 'optic':opticSNDElo, 'midnight':midnightSNDElo, 'uyu':uyuSNDElo, 'rec':recSNDElo, 'gen g':gengSNDElo, 'lg':luminSNDElo, 'eunited':eunitedSNDElo, 'e6':e6SNDElo, 'heretics':hereticsSNDElo, 'nv':nvSNDElo, 'splyce':splyceSNDElo, 'denial':denialSNDElo, 'excel':excelSNDElo, 'eg':egSNDElo}
        sorted_control = sorted(controlElos.items(), key=operator.itemgetter(1), reverse = True)
        sorted_hp = sorted(hpElos.items(), key=operator.itemgetter(1), reverse = True)
        sorted_snd = sorted(sndElos.items(), key=operator.itemgetter(1), reverse = True)
        print ('HP: ')
        for teams, elos in sorted_hp:
            print teams, ':', elos
        print '\n'
        print ('SND: ')
        for teams, elos in sorted_snd:
            print teams, ':', elos
        print '\n'
        print ('Control: ')
        for teams, elos in sorted_control:
            print teams, ':', elos

# %%
#PRE-TOURNEY ELOS
showUpdatedElos()
# Out:
# HP:
# midnight : 1313.27047332
# thieves : 1307.18768965
# eunited : 1254.41664944
# optic : 1249.68800402
# heretics : 1238.38288435
# red : 1221.5995546
# nv : 1221.18900327
# eg : 1212.76642558
# e6 : 1188.5659788
# splyce : 1185.90826004
# uyu : 1180.06187031
# gen g : 1176.23320024
# denial : 1169.15807274
# lg : 1145.64911319
# rec : 1100.73135875
# excel : 1035.1914617
#
#
# SND:
# gen g : 1340.48334341
# eunited : 1262.33116183
# rec : 1258.38710574
# red : 1229.70413885
# excel : 1217.61722371
# thieves : 1206.99893286
# splyce : 1206.74885904
# heretics : 1202.33571995
# optic : 1200.95545455
# nv : 1200.23794381
# lg : 1196.3537873
# denial : 1186.46125685
# midnight : 1175.87363314
# uyu : 1133.41370752
# e6 : 1117.26890197
# eg : 1064.82882949
#
#
# Control:
# lg : 1292.35336518
# thieves : 1260.3454627
# red : 1256.80696411
# optic : 1231.07007947
# nv : 1226.95904734
# e6 : 1224.31570954
# midnight : 1218.63024623
# uyu : 1213.55787509
# heretics : 1212.80046355
# ...

# %%
#Midnight complete roster change
midnightHPElo = 1150
midnightSNDElo = 1200
midnightCNTRLElo = 1150

#Excel complete roster change
excelHPElo = 1200
excelSNDElo = 1200
excelCNTRLElo = 1200

# %%
thievesHPElo, egHPElo = EloRating(thievesHPElo, egHPElo)
thievesSNDElo, egSNDElo = EloRating(thievesSNDElo, egSNDElo)
thievesCNTRLElo, egCNTRLElo = EloRating(thievesCNTRLElo, egCNTRLElo)

# %%
print thievesHPElo
# Out:
# 1321.88233841

# %%
redHPElo, e6HPElo = EloRating(redHPElo, e6HPElo)
e6SNDElo, redSNDElo = EloRating(e6SNDElo, redSNDElo)
e6CNTRLElo, redCNTRLElo = EloRating(e6CNTRLElo, redCNTRLElo)
redHPElo, e6HPElo = EloRating(redHPElo, e6HPElo)
e6SNDElo, redSNDElo = EloRating(e6SNDElo, redSNDElo)
print redHPElo, redSNDElo
# Out:
# 1255.76976187 1180.03298568

# %%
luminHPElo, excelHPElo = EloRating(luminHPElo, excelHPElo)
excelSNDElo, luminSNDElo = EloRating(excelSNDElo, luminSNDElo)
luminCNTRLElo, excelCNTRLElo = EloRating(luminCNTRLElo, excelCNTRLElo)
excelHPElo, luminHPElo = EloRating(excelHPElo, luminHPElo)
luminSNDElo, excelSNDElo = EloRating(luminSNDElo, excelSNDElo)
print excelHPElo, excelCNTRLElo
# Out:
# 1196.42786174 1185.19451605

# %%
splyceHPElo, midnightHPElo = EloRating(splyceHPElo, midnightHPElo)
midnightSNDElo, splyceSNDElo = EloRating(midnightSNDElo, splyceSNDElo)
splyceCNTRLElo, midnightCNTRLElo = EloRating(splyceCNTRLElo, midnightCNTRLElo)
midnightHPElo, splyceHPElo = EloRating(midnightHPElo, splyceHPElo)
splyceSNDElo, midnightSNDElo = EloRating(splyceSNDElo, midnightSNDElo)

# %%
print ('Elos after day 1 1st matches')
printelos()
# Out:
# Elos after day 1 1st matches
# HP
#
# 100T HP Elo: 1321.88233841
# RR HP Elo: 1255.76976187
# Optic HP Elo: 1249.68800402
# Midnight HP Elo: 1156.13439065
# UYU HP Elo: 1180.06187031
# REC HP Elo: 1100.73135875
# GEN.G HP Elo: 1176.23320024
# LG HP Elo: 1149.22125144
# eU HP Elo: 1254.41664944
# E6 HP Elo: 1154.39577153
# Heretics HP Elo: 1238.38288435
# nv HP Elo: 1221.18900327
# Splyce HP Elo: 1179.77386939
# Denial HP Elo: 1169.15807274
# Excel HP Elo: 1196.42786174
# EG HP Elo: 1198.07177683
#
#
# SND
#
# 100T SND Elo: 1219.24309522
# RR SND Elo: 1180.03298568
# Optic SND Elo: 1200.95545455
# Midnight SND Elo: 1198.43587485
# UYU SND Elo: 1133.41370752
# REC SND Elo: 1258.38710574
# GEN.G SND Elo: 1340.48334341
# LG SND Elo: 1199.03922642
# eU SND Elo: 1262.33116183
# E6 SND Elo: 1166.94005514
# Heretics SND Elo: 1202.33571995
# nv SND Elo: 1200.23794381
# Splyce SND Elo: 1208.31298419
# Denial SND Elo: 1186.46125685
# Excel SND Elo: 1197.31456088
# EG SND Elo: 1052.58466713
#
#
# ...

# %%
hereticsHPElo, gengHPElo = EloRating(hereticsHPElo, gengHPElo)
gengSNDElo, hereticsSNDElo = EloRating(gengSNDElo, hereticsSNDElo)
hereticsCNTRLElo, gengCNTRLElo = EloRating(hereticsCNTRLElo, gengCNTRLElo)
gengHPElo, hereticsHPElo = EloRating(gengHPElo, hereticsHPElo)
gengSNDElo, hereticsSNDElo = EloRating(gengSNDElo, hereticsSNDElo)

# %%
opticHPElo, recHPElo = EloRating(opticHPElo, recHPElo)
recSNDElo, opticSNDElo = EloRating(recSNDElo, opticSNDElo)
opticCNTRLElo, recCNTRLElo = EloRating(opticCNTRLElo, recCNTRLElo)
recHPElo, opticHPElo = EloRating(recHPElo, opticHPElo)
recSNDElo, opticSNDElo = EloRating(recSNDElo, opticSNDElo)

# %%
denialHPElo, uyuHPElo = EloRating(denialHPElo, uyuHPElo)
uyuSNDElo, denialSNDElo = EloRating(uyuSNDElo, denialSNDElo)
uyuCNTRLElo, denialCNTRLElo = EloRating(uyuCNTRLElo, denialCNTRLElo)
denialHPElo, uyuHPElo = EloRating(denialHPElo, uyuHPElo)
denialSNDElo, uyuSNDElo = EloRating(denialSNDElo, uyuSNDElo)

# %%
nvHPElo, eunitedHPElo = EloRating(nvHPElo, eunitedHPElo)
nvSNDElo, eunitedSNDElo = EloRating(nvSNDElo, eunitedSNDElo)
nvCNTRLElo, eunitedCNTRLElo = EloRating(nvCNTRLElo, eunitedCNTRLElo)

# %%
print ('Elos after day 1 2nd matches')
printelos()
# Out:
# Elos after day 1 2nd matches
# HP
#
# 100T HP Elo: 1321.88233841
# RR HP Elo: 1255.76976187
# Optic HP Elo: 1232.40267084
# Midnight HP Elo: 1156.13439065
# UYU HP Elo: 1141.17712427
# REC HP Elo: 1118.01669193
# GEN.G HP Elo: 1185.11318566
# LG HP Elo: 1149.22125144
# eU HP Elo: 1232.50972267
# E6 HP Elo: 1154.39577153
# Heretics HP Elo: 1229.50289893
# nv HP Elo: 1243.09593004
# Splyce HP Elo: 1179.77386939
# Denial HP Elo: 1208.04281878
# Excel HP Elo: 1196.42786174
# EG HP Elo: 1198.07177683
#
#
# SND
#
# 100T SND Elo: 1219.24309522
# RR SND Elo: 1180.03298568
# Optic SND Elo: 1169.34699144
# Midnight SND Elo: 1198.43587485
# UYU SND Elo: 1136.8460239
# REC SND Elo: 1289.99556885
# GEN.G SND Elo: 1364.17339141
# LG SND Elo: 1199.03922642
# eU SND Elo: 1238.79436445
# E6 SND Elo: 1166.94005514
# Heretics SND Elo: 1178.64567194
# nv SND Elo: 1223.77474118
# Splyce SND Elo: 1208.31298419
# Denial SND Elo: 1183.02894047
# Excel SND Elo: 1197.31456088
# EG SND Elo: 1052.58466713
#
#
# ...

# %%
thievesHPElo, redHPElo = EloRating(thievesHPElo, redHPElo)
redSNDElo, thievesSNDElo = EloRating(redSNDElo, thievesSNDElo)
redCNTRLElo, thievesCNTRLElo = EloRating(redCNTRLElo, thievesCNTRLElo)
redHPElo, thievesHPElo = EloRating(redHPElo, thievesHPElo)

# %%
luminHPElo, midnightHPElo = EloRating(luminHPElo, midnightHPElo)
luminSNDElo, midnightSNDElo = EloRating(luminSNDElo, midnightSNDElo)
luminCNTRLElo, midnightCNTRLElo = EloRating(luminCNTRLElo, midnightCNTRLElo)

# %%
splyceHPElo, excelHPElo = EloRating(splyceHPElo, excelHPElo)
excelSNDElo, splyceSNDElo = EloRating(excelSNDElo, splyceSNDElo)
splyceCNTRLElo, excelCNTRLElo = EloRating(splyceCNTRLElo, excelCNTRLElo)
splyceHPElo, excelHPElo = EloRating(splyceHPElo, excelHPElo)

# %%
egHPElo, e6HPElo = EloRating(egHPElo, e6HPElo)
egSNDElo, e6SNDElo = EloRating(egSNDElo, e6SNDElo)
e6CNTRLElo, egCNTRLElo = EloRating(e6CNTRLElo, egCNTRLElo)
e6HPElo, egHPElo = EloRating(e6HPElo, egHPElo)
e6SNDElo, egSNDElo = EloRating(e6SNDElo, egSNDElo)

# %%
print ('Elos after day 1 3rd matches')
printelos()
# Out:
# Elos after day 1 3rd matches
# HP
#
# 100T HP Elo: 1312.59406549
# RR HP Elo: 1265.05803479
# Optic HP Elo: 1232.40267084
# Midnight HP Elo: 1135.73649088
# UYU HP Elo: 1141.17712427
# REC HP Elo: 1118.01669193
# GEN.G HP Elo: 1185.11318566
# LG HP Elo: 1169.61915122
# eU HP Elo: 1232.50972267
# E6 HP Elo: 1161.34978855
# Heretics HP Elo: 1229.50289893
# nv HP Elo: 1243.09593004
# Splyce HP Elo: 1219.28018191
# Denial HP Elo: 1208.04281878
# Excel HP Elo: 1156.92154923
# EG HP Elo: 1191.1177598
#
#
# SND
#
# 100T SND Elo: 1196.99551384
# RR SND Elo: 1202.28056706
# Optic SND Elo: 1169.34699144
# Midnight SND Elo: 1178.47060652
# UYU SND Elo: 1136.8460239
# REC SND Elo: 1289.99556885
# GEN.G SND Elo: 1364.17339141
# LG SND Elo: 1219.00449475
# eU SND Elo: 1238.79436445
# E6 SND Elo: 1157.07325502
# Heretics SND Elo: 1178.64567194
# nv SND Elo: 1223.77474118
# Splyce SND Elo: 1187.68007545
# Denial SND Elo: 1183.02894047
# Excel SND Elo: 1217.94746962
# EG SND Elo: 1062.45146724
#
#
# ...

# %%
nvHPElo, opticHPElo = EloRating(nvHPElo, opticHPElo)
nvSNDElo, opticSNDElo = EloRating(nvSNDElo, opticSNDElo)
opticCNTRLElo, nvCNTRLElo = EloRating(opticCNTRLElo, nvCNTRLElo)
nvHPElo, opticHPElo = EloRating(nvHPElo, opticHPElo)

# %%
recHPElo, eunitedHPElo = EloRating(recHPElo, eunitedHPElo)
eunitedSNDElo, recSNDElo = EloRating(eunitedSNDElo, recSNDElo)
recCNTRLElo, eunitedCNTRLElo = EloRating(recCNTRLElo, eunitedCNTRLElo)
eunitedHPElo, recHPElo = EloRating(eunitedHPElo, recHPElo)
eunitedSNDElo, recSNDElo = EloRating(eunitedSNDElo, recSNDElo)

# %%
uyuHPElo, hereticsHPElo = EloRating(uyuHPElo, hereticsHPElo)
uyuSNDElo, hereticsSNDElo = EloRating(uyuSNDElo, hereticsSNDElo)
uyuCNTRLElo, hereticsCNTRLElo = EloRating(uyuCNTRLElo, hereticsCNTRLElo)

# %%
gengHPElo, denialHPElo = EloRating(gengHPElo, denialHPElo)
gengSNDElo, denialSNDElo = EloRating(gengSNDElo, denialSNDElo)
gengCNTRLElo, denialCNTRLElo = EloRating(gengCNTRLElo, denialCNTRLElo)

# %%
print ('Elos after day 1 4th matches')
printelos()
# Out:
# Elos after day 1 4th matches
# HP
#
# 100T HP Elo: 1312.59406549
# RR HP Elo: 1265.05803479
# Optic HP Elo: 1195.84624142
# Midnight HP Elo: 1135.73649088
# UYU HP Elo: 1166.15479019
# REC HP Elo: 1127.89749843
# GEN.G HP Elo: 1206.43120842
# LG HP Elo: 1169.61915122
# eU HP Elo: 1222.62891617
# E6 HP Elo: 1161.34978855
# Heretics HP Elo: 1204.52523301
# nv HP Elo: 1279.65235946
# Splyce HP Elo: 1219.28018191
# Denial HP Elo: 1186.72479603
# Excel HP Elo: 1156.92154923
# EG HP Elo: 1191.1177598
#
#
# SND
#
# 100T SND Elo: 1196.99551384
# RR SND Elo: 1202.28056706
# Optic SND Elo: 1152.45472379
# Midnight SND Elo: 1178.47060652
# UYU SND Elo: 1159.24066265
# REC SND Elo: 1246.76146883
# GEN.G SND Elo: 1374.59817066
# LG SND Elo: 1219.00449475
# eU SND Elo: 1282.02846448
# E6 SND Elo: 1157.07325502
# Heretics SND Elo: 1156.2510332
# nv SND Elo: 1240.66700883
# Splyce SND Elo: 1187.68007545
# Denial SND Elo: 1172.60416121
# Excel SND Elo: 1217.94746962
# EG SND Elo: 1062.45146724
#
#
# ...

# %%
splyceHPElo, luminHPElo = EloRating(splyceHPElo, luminHPElo)
splyceSNDElo, luminSNDElo = EloRating(splyceSNDElo, luminSNDElo)
luminCNTRLElo, splyceCNTRLElo = EloRating(luminCNTRLElo, splyceCNTRLElo)
splyceHPElo, luminHPElo = EloRating(splyceHPElo, luminHPElo)

# %%
redHPElo, egHPElo = EloRating(redHPElo, egHPElo)
redSNDElo, egSNDElo = EloRating(redSNDElo, egSNDElo)
redCNTRLElo, egCNTRLElo = EloRating(redCNTRLElo, egCNTRLElo)

# %%
excelHPElo, midnightHPElo = EloRating(excelHPElo, midnightHPElo)
excelSNDElo, midnightSNDElo = EloRating(excelSNDElo, midnightSNDElo)
excelCNTRLElo, midnightCNTRLElo = EloRating(excelCNTRLElo, midnightCNTRLElo)

# %%
e6HPElo, thievesHPElo = EloRating(e6HPElo, thievesHPElo)
thievesSNDElo, e6SNDElo = EloRating(thievesSNDElo, e6SNDElo)
e6CNTRLElo, thievesCNTRLElo = EloRating(e6CNTRLElo, thievesCNTRLElo)
thievesHPElo, e6HPElo = EloRating(thievesHPElo, e6HPElo)
thievesSNDElo, e6SNDElo = EloRating(thievesSNDElo, e6SNDElo)

# %%
print ('Elos after day 1 5th matches')
printelos()
# Out:
# Elos after day 1 5th matches
# HP
#
# 100T HP Elo: 1299.07047122
# RR HP Elo: 1280.86480551
# Optic HP Elo: 1195.84624142
# Midnight HP Elo: 1116.95449173
# UYU HP Elo: 1166.15479019
# REC HP Elo: 1127.89749843
# GEN.G HP Elo: 1206.43120842
# LG HP Elo: 1137.20095787
# eU HP Elo: 1222.62891617
# E6 HP Elo: 1174.87338282
# Heretics HP Elo: 1204.52523301
# nv HP Elo: 1279.65235946
# Splyce HP Elo: 1251.69837526
# Denial HP Elo: 1186.72479603
# Excel HP Elo: 1175.70354838
# EG HP Elo: 1175.31098908
#
#
# SND
#
# 100T SND Elo: 1230.43692985
# RR SND Elo: 1214.63952123
# Optic SND Elo: 1152.45472379
# Midnight SND Elo: 1160.73334824
# UYU SND Elo: 1159.24066265
# REC SND Elo: 1246.76146883
# GEN.G SND Elo: 1374.59817066
# LG SND Elo: 1197.20618619
# eU SND Elo: 1282.02846448
# E6 SND Elo: 1123.63183901
# Heretics SND Elo: 1156.2510332
# nv SND Elo: 1240.66700883
# Splyce SND Elo: 1209.47838401
# Denial SND Elo: 1172.60416121
# Excel SND Elo: 1235.6847279
# EG SND Elo: 1050.09251308
#
#
# ...

# %%
opticHPElo, eunitedHPElo = EloRating(opticHPElo, eunitedHPElo)
opticSNDElo, eunitedSNDElo = EloRating(opticSNDElo, eunitedSNDElo)
opticCNTRLElo, eunitedCNTRLElo = EloRating(opticCNTRLElo, eunitedCNTRLElo)

# %%
denialHPElo, hereticsHPElo = EloRating(denialHPElo, hereticsHPElo)
denialSNDElo, hereticsSNDElo = EloRating(denialSNDElo, hereticsSNDElo)
hereticsCNTRLElo, denialCNTRLElo = EloRating(hereticsCNTRLElo, denialCNTRLElo)
denialHPElo, hereticsHPElo = EloRating(denialHPElo, hereticsHPElo)

# %%
recHPElo, nvHPElo = EloRating(recHPElo, nvHPElo)
recSNDElo, nvSNDElo = EloRating(recSNDElo, nvSNDElo)
nvCNTRLElo, recCNTRLElo = EloRating(nvCNTRLElo, recCNTRLElo)
nvHPElo, recHPElo = EloRating(nvHPElo, recHPElo)
recSNDElo, nvSNDElo = EloRating(recSNDElo, nvSNDElo)

# %%
gengHPElo, uyuHPElo = EloRating(gengHPElo, uyuHPElo)
uyuSNDElo, gengSNDElo = EloRating(uyuSNDElo, gengSNDElo)
gengCNTRLElo, uyuCNTRLElo = EloRating(gengCNTRLElo, uyuCNTRLElo)
gengHPElo, uyuHPElo = EloRating(gengHPElo, uyuHPElo)

# %%
print ('Elos after day 1 6th matches (Final) \n')
printelos()
# Out:
# Elos after day 1 6th matches (Final)
#
# HP
#
# 100T HP Elo: 1299.07047122
# RR HP Elo: 1280.86480551
# Optic HP Elo: 1217.38492951
# Midnight HP Elo: 1116.95449173
# UYU HP Elo: 1132.7507357
# REC HP Elo: 1141.47021703
# GEN.G HP Elo: 1239.83526291
# LG HP Elo: 1137.20095787
# eU HP Elo: 1201.09022809
# E6 HP Elo: 1174.87338282
# Heretics HP Elo: 1164.89496806
# nv HP Elo: 1266.07964085
# Splyce HP Elo: 1251.69837526
# Denial HP Elo: 1226.35506097
# Excel HP Elo: 1175.70354838
# EG HP Elo: 1175.31098908
#
#
# SND
#
# 100T SND Elo: 1230.43692985
# RR SND Elo: 1214.63952123
# Optic SND Elo: 1179.58599213
# Midnight SND Elo: 1160.73334824
# UYU SND Elo: 1190.26111665
# REC SND Elo: 1283.81242225
# GEN.G SND Elo: 1343.57771666
# LG SND Elo: 1197.20618619
# eU SND Elo: 1254.89719614
# E6 SND Elo: 1123.63183901
# Heretics SND Elo: 1137.19170037
# nv SND Elo: 1203.61605541
# Splyce SND Elo: 1209.47838401
# Denial SND Elo: 1191.66349404
# Excel SND Elo: 1235.6847279
# ...

# %%
#winChance(gengHPElo,luminHPElo)
#winChance(gengSNDElo, luminSNDElo)
#winChance(gengCNTRLElo, luminCNTRLElo)

# %%
#winChance(e6HPElo,recHPElo)
#winChance(e6SNDElo, recSNDElo)
#winChance(e6CNTRLElo, recCNTRLElo)

# %%
#winChance(splyceHPElo,denialHPElo)
#winChance(splyceSNDElo, denialSNDElo)
#winChance(splyceCNTRLElo, denialCNTRLElo)

# %%
#winChance(nvHPElo,redHPElo)
#winChance(nvSNDElo, redSNDElo)
#winChance(nvCNTRLElo, redCNTRLElo)

# %%
#winChance(excelHPElo,hereticsHPElo)
#winChance(excelSNDElo, hereticsSNDElo)
#winChance(excelCNTRLElo, hereticsCNTRLElo)

# %%
#winChance(eunitedHPElo,thievesHPElo)
#winChance(eunitedSNDElo, thievesSNDElo)
#winChance(eunitedCNTRLElo, thievesCNTRLElo)

# %%
#winChance(uyuHPElo,midnightHPElo)
#winChance(uyuSNDElo, midnightSNDElo)
#winChance(uyuCNTRLElo, midnightCNTRLElo)

# %%
#winChance(opticHPElo,egHPElo)
#winChance(opticSNDElo, egSNDElo)
winChance(opticCNTRLElo, egCNTRLElo)
# Out:
# 'chance of team 2 to win: 0.254394516246'

# %%
gengHPElo, luminHPElo = EloRating(gengHPElo, luminHPElo)
luminSNDElo, gengSNDElo = EloRating(luminSNDElo, gengSNDElo)
luminCNTRLElo, gengCNTRLElo = EloRating(luminCNTRLElo, gengCNTRLElo)
gengHPElo, luminHPElo = EloRating(gengHPElo, luminHPElo)
luminSNDElo, gengSNDElo = EloRating(luminSNDElo, gengSNDElo)

# %%
e6HPElo, recHPElo = EloRating(e6HPElo, recHPElo)
e6SNDElo, recSNDElo = EloRating(e6SNDElo, recSNDElo)
e6CNTRLElo, recCNTRLElo = EloRating(e6CNTRLElo, recCNTRLElo)

# %%
uyuHPElo, midnightHPElo = EloRating(uyuHPElo, midnightHPElo)
uyuSNDElo, midnightSNDElo = EloRating(uyuSNDElo, midnightSNDElo)
uyuCNTRLElo, midnightCNTRLElo = EloRating(uyuCNTRLElo, midnightCNTRLElo)

# %%
opticHPElo, egHPElo = EloRating(opticHPElo, egHPElo)
opticSNDElo, egSNDElo = EloRating(opticSNDElo, egSNDElo)
opticCNTRLElo, egCNTRLElo = EloRating(opticCNTRLElo, egCNTRLElo)

# %%
print ('Elos after day 2 1st matches \n')
printelos()
# Out:
# Elos after day 2 1st matches
#
# HP
#
# 100T HP Elo: 1299.07047122
# RR HP Elo: 1280.86480551
# Optic HP Elo: 1234.97472905
# Midnight HP Elo: 1097.86317061
# UYU HP Elo: 1151.84205683
# REC HP Elo: 1123.38715518
# GEN.G HP Elo: 1266.88286733
# LG HP Elo: 1110.15335344
# eU HP Elo: 1201.09022809
# E6 HP Elo: 1192.95644467
# Heretics HP Elo: 1164.89496806
# nv HP Elo: 1266.07964085
# Splyce HP Elo: 1251.69837526
# Denial HP Elo: 1226.35506097
# Excel HP Elo: 1175.70354838
# EG HP Elo: 1157.72118953
#
#
# SND
#
# 100T SND Elo: 1230.43692985
# RR SND Elo: 1214.63952123
# Optic SND Elo: 1192.45875695
# Midnight SND Elo: 1142.42902261
# UYU SND Elo: 1208.56544227
# REC SND Elo: 1255.19384549
# GEN.G SND Elo: 1290.52512443
# LG SND Elo: 1250.25877842
# eU SND Elo: 1254.89719614
# E6 SND Elo: 1152.25041577
# Heretics SND Elo: 1137.19170037
# nv SND Elo: 1203.61605541
# Splyce SND Elo: 1209.47838401
# Denial SND Elo: 1191.66349404
# Excel SND Elo: 1235.6847279
# EG SND Elo: 1037.21974826
#
# ...

# %%
redHPElo, nvHPElo = EloRating(redHPElo, nvHPElo)
redSNDElo, nvSNDElo = EloRating(redSNDElo, nvSNDElo)
redCNTRLElo, nvCNTRLElo = EloRating(redCNTRLElo, nvCNTRLElo)

# %%
splyceHPElo, denialHPElo = EloRating(splyceHPElo, denialHPElo)
denialSNDElo, splyceSNDElo = EloRating(denialSNDElo, splyceSNDElo)
splyceCNTRLElo, denialCNTRLElo = EloRating(splyceCNTRLElo, denialCNTRLElo)
denialHPElo, splyceHPElo = EloRating(denialHPElo, splyceHPElo)
splyceSNDElo, denialSNDElo = EloRating(splyceSNDElo, denialSNDElo)

# %%
thievesHPElo, eunitedHPElo = EloRating(thievesHPElo, eunitedHPElo)
thievesSNDElo, eunitedSNDElo = EloRating(thievesSNDElo, eunitedSNDElo)
eunitedCNTRLElo, thievesCNTRLElo = EloRating(eunitedCNTRLElo, thievesCNTRLElo)
thievesHPElo, eunitedHPElo = EloRating(thievesHPElo, eunitedHPElo)

# %%
hereticsHPElo, excelHPElo = EloRating(hereticsHPElo, excelHPElo)
hereticsSNDElo, excelSNDElo = EloRating(hereticsSNDElo, excelSNDElo)
excelCNTRLElo, hereticsCNTRLElo = EloRating(excelCNTRLElo, hereticsCNTRLElo)
excelHPElo, hereticsHPElo = EloRating(excelHPElo, hereticsHPElo)
hereticsSNDElo, excelSNDElo = EloRating(hereticsSNDElo, excelSNDElo)

# %%
print ('Elos after day 2 2nd matches \n')
printelos()
# Out:
# Elos after day 2 2nd matches
#
# HP
#
# 100T HP Elo: 1326.57410101
# RR HP Elo: 1300.01421641
# Optic HP Elo: 1234.97472905
# Midnight HP Elo: 1097.86317061
# UYU HP Elo: 1151.84205683
# REC HP Elo: 1123.38715518
# GEN.G HP Elo: 1266.88286733
# LG HP Elo: 1110.15335344
# eU HP Elo: 1173.5865983
# E6 HP Elo: 1192.95644467
# Heretics HP Elo: 1163.76942451
# nv HP Elo: 1246.93022996
# Splyce HP Elo: 1246.68646397
# Denial HP Elo: 1231.36697225
# Excel HP Elo: 1176.82909193
# EG HP Elo: 1157.72118953
#
#
# SND
#
# 100T SND Elo: 1251.84265425
# RR SND Elo: 1234.00517237
# Optic SND Elo: 1192.45875695
# Midnight SND Elo: 1142.42902261
# UYU SND Elo: 1208.56544227
# REC SND Elo: 1255.19384549
# GEN.G SND Elo: 1290.52512443
# LG SND Elo: 1250.25877842
# eU SND Elo: 1233.49147174
# E6 SND Elo: 1152.25041577
# Heretics SND Elo: 1185.42872929
# nv SND Elo: 1184.25040426
# Splyce SND Elo: 1209.8465564
# Denial SND Elo: 1191.29532166
# Excel SND Elo: 1187.44769898
# EG SND Elo: 1037.21974826
#
#
# ...

# %%
gengHPElo, opticHPElo = EloRating(gengHPElo, opticHPElo)
opticSNDElo, gengSNDElo = EloRating(opticSNDElo, gengSNDElo)
gengCNTRLElo, opticCNTRLElo = EloRating(gengCNTRLElo, opticCNTRLElo)
opticHPElo, gengHPElo = EloRating(opticHPElo, gengHPElo)
gengSNDElo, opticSNDElo = EloRating(gengSNDElo, opticSNDElo)

# %%
uyuHPElo, recHPElo = EloRating(uyuHPElo, recHPElo)
recSNDElo, uyuSNDElo = EloRating(recSNDElo, uyuSNDElo)
uyuCNTRLElo, recCNTRLElo = EloRating(uyuCNTRLElo, recCNTRLElo)
recHPElo, uyuHPElo = EloRating(recHPElo, uyuHPElo)
recSNDElo, uyuSNDElo = EloRating(recSNDElo, uyuSNDElo)

# %%
hereticsHPElo, nvHPElo = EloRating(hereticsHPElo, nvHPElo)
hereticsSNDElo, nvSNDElo = EloRating(hereticsSNDElo, nvSNDElo)
nvCNTRLElo, hereticsCNTRLElo = EloRating(nvCNTRLElo, hereticsCNTRLElo)
hereticsHPElo, nvHPElo = EloRating(hereticsHPElo, nvHPElo)

# %%
thievesHPElo, denialHPElo = EloRating(thievesHPElo, denialHPElo)
thievesSNDElo, denialSNDElo = EloRating(thievesSNDElo, denialSNDElo)
thievesCNTRLElo, denialCNTRLElo = EloRating(thievesCNTRLElo, denialCNTRLElo)

# %%
print ('Elos after day 2 3rd matches \n')
printelos()
# Out:
# Elos after day 2 3rd matches
#
# HP
#
# 100T HP Elo: 1341.2267203
# RR HP Elo: 1300.01421641
# Optic HP Elo: 1240.68509701
# Midnight HP Elo: 1097.86317061
# UYU HP Elo: 1146.49871255
# REC HP Elo: 1128.73049946
# GEN.G HP Elo: 1261.17249938
# LG HP Elo: 1110.15335344
# eU HP Elo: 1173.5865983
# E6 HP Elo: 1192.95644467
# Heretics HP Elo: 1210.40476391
# nv HP Elo: 1200.29489056
# Splyce HP Elo: 1246.68646397
# Denial HP Elo: 1216.71435296
# Excel HP Elo: 1176.82909193
# EG HP Elo: 1157.72118953
#
#
# SND
#
# 100T SND Elo: 1268.39212963
# RR SND Elo: 1234.00517237
# Optic SND Elo: 1200.6515438
# Midnight SND Elo: 1142.42902261
# UYU SND Elo: 1175.82957366
# REC SND Elo: 1287.9297141
# GEN.G SND Elo: 1282.33233757
# LG SND Elo: 1250.25877842
# eU SND Elo: 1233.49147174
# E6 SND Elo: 1152.25041577
# Heretics SND Elo: 1205.36089971
# nv SND Elo: 1164.31823384
# Splyce SND Elo: 1209.8465564
# Denial SND Elo: 1174.74584627
# Excel SND Elo: 1187.44769898
# EG SND Elo: 1037.21974826
#
#
# ...

# %%
#winChance(gengHPElo,recHPElo)
#winChance(gengSNDElo, recSNDElo)
#winChance(gengCNTRLElo, recCNTRLElo)

# %%
thievesHPElo, hereticsHPElo = EloRating(thievesHPElo, hereticsHPElo)
thievesSNDElo, hereticsSNDElo = EloRating(thievesSNDElo, hereticsSNDElo)
thievesCNTRLElo, hereticsCNTRLElo = EloRating(thievesCNTRLElo, hereticsCNTRLElo)

# %%
luminHPElo, e6HPElo = EloRating(luminHPElo, e6HPElo)
luminSNDElo, e6SNDElo = EloRating(luminSNDElo, e6SNDElo)
luminCNTRLElo, e6CNTRLElo = EloRating(luminCNTRLElo, e6CNTRLElo)

# %%
splyceHPElo, redHPElo = EloRating(splyceHPElo, redHPElo)
splyceSNDElo, redSNDElo = EloRating(splyceSNDElo, redSNDElo)
spyceCNTRLElo, redCNTRLElo = EloRating(splyceCNTRLElo, redCNTRLElo)

# %%
gengHPElo, recHPElo = EloRating(gengHPElo, recHPElo)
recSNDElo, gengSNDElo = EloRating(recSNDElo, gengSNDElo)
recCNTRLElo, gengCNTRLElo = EloRating(recCNTRLElo, gengCNTRLElo)
gengHPElo, recHPElo = EloRating(gengHPElo, recHPElo)
recSNDElo, gengSNDElo = EloRating(recSNDElo, gengSNDElo)

# %%
print ('end of day 2 elos:')
showUpdatedElos()
# Out:
# end of day 2 elos:
# HP:
# thieves : 1354.03281462
# gen g : 1285.38653916
# red : 1276.96830632
# splyce : 1269.73237406
# optic : 1240.68509701
# denial : 1216.71435296
# nv : 1200.29489056
# heretics : 1197.5986696
# excel : 1176.82909193
# eunited : 1173.5865983
# e6 : 1168.27815679
# eg : 1157.72118953
# uyu : 1146.49871255
# lg : 1134.83164132
# rec : 1104.51645967
# midnight : 1097.86317061
#
#
# SND:
# rec : 1325.03417158
# thieves : 1284.80304963
# lg : 1264.76199832
# gen g : 1245.22788009
# eunited : 1233.49147174
# splyce : 1231.23500114
# red : 1212.61672763
# optic : 1200.6515438
# heretics : 1188.94997971
# excel : 1187.44769898
# uyu : 1175.82957366
# denial : 1174.74584627
# nv : 1164.31823384
# midnight : 1142.42902261
# e6 : 1137.74719587
# eg : 1037.21974826
#
#
# Control:
# lg : 1364.44455549
# e6 : 1272.79689086
# red : 1264.20396325
# optic : 1262.18852022
# uyu : 1252.72374718
# splyce : 1240.27721341
# nv : 1237.95240524
# thieves : 1235.30813874
# ...

# %%
#winChance(recHPElo,redHPElo)
#winChance(recSNDElo, redSNDElo)
#winChance(recCNTRLElo, redCNTRLElo)

# %%
recHPElo, redHPElo = EloRating(recHPElo, redHPElo)
redSNDElo, recSNDElo = EloRating(redSNDElo, recSNDElo)
recCNTRLElo, redCNTRLElo = EloRating(recCNTRLElo, redCNTRLElo)
redHPElo, recHPElo = EloRating(redHPElo, recHPElo)
recSNDElo, redSNDElo = EloRating(recSNDElo, redSNDElo)

# %%
thievesHPElo, e6HPElo = EloRating(thievesHPElo, e6HPElo)
thievesSNDElo, e6SNDElo = EloRating(thievesSNDElo, e6SNDElo)
e6CNTRLElo, thievesCNTRLElo = EloRating(e6CNTRLElo, thievesCNTRLElo)
thievesHPElo, e6HPElo = EloRating(thievesHPElo, e6HPElo)

# %%
recHPElo, thievesHPElo = EloRating(recHPElo, thievesHPElo)
recSNDElo, thievesSNDElo = EloRating(recSNDElo, thievesSNDElo)
thievesCNTRLElo, recCNTRLElo = EloRating(thievesCNTRLElo, recCNTRLElo)
recHPElo, thievesHPElo = EloRating(recHPElo, thievesHPElo)

# %%
#winChance(recHPElo,splyceHPElo)
#winChance(recSNDElo, splyceSNDElo)
#winChance(recCNTRLElo, splyceCNTRLElo)

# %%
showUpdatedElos()
# Out:
# HP:
# thieves : 1311.24272551
# gen g : 1285.38653916
# splyce : 1269.73237406
# red : 1261.44254521
# optic : 1240.68509701
# denial : 1216.71435296
# nv : 1200.29489056
# heretics : 1197.5986696
# rec : 1182.40589234
# excel : 1176.82909193
# eunited : 1173.5865983
# eg : 1157.72118953
# e6 : 1148.70457434
# uyu : 1146.49871255
# lg : 1134.83164132
# midnight : 1097.86317061
#
#
# SND:
# rec : 1334.29772119
# thieves : 1277.8766841
# lg : 1264.76199832
# gen g : 1245.22788009
# eunited : 1233.49147174
# splyce : 1231.23500114
# red : 1222.28606565
# optic : 1200.6515438
# heretics : 1188.94997971
# excel : 1187.44769898
# uyu : 1175.82957366
# denial : 1174.74584627
# nv : 1164.31823384
# midnight : 1142.42902261
# e6 : 1125.74067378
# eg : 1037.21974826
#
#
# Control:
# lg : 1364.44455549
# e6 : 1290.64720107
# optic : 1262.18852022
# uyu : 1252.72374718
# splyce : 1240.27721341
# nv : 1237.95240524
# red : 1236.13843474
# thieves : 1233.27582346
# gen g : 1209.68444257
# ...

# %%
recHPElo, splyceHPElo = EloRating(recHPElo, splyceHPElo)
recSNDElo, splyceSNDElo = EloRating(recSNDElo, splyceSNDElo)
splyceCNTRLElo, recCNTRLElo = EloRating(splyceCNTRLElo, recCNTRLElo)
splyceHPElo, recHPElo = EloRating(splyceHPElo, recHPElo)
splyceSNDElo, recSNDElo = EloRating(splyceSNDElo, recSNDElo)

# %%
#winChance(luminHPElo,splyceHPElo)
#winChance(luminSNDElo, splyceSNDElo)
#winChance(luminCNTRLElo, splyceCNTRLElo)

# %%
luminHPElo, splyceHPElo = EloRating(luminHPElo, splyceHPElo)
luminSNDElo, splyceSNDElo = EloRating(luminSNDElo, splyceSNDElo)
splyceCNTRLElo, luminCNTRLElo = EloRating(splyceCNTRLElo, luminCNTRLElo)
luminHPElo, splyceHPElo = EloRating(luminHPElo, splyceHPElo)

# %%
#POST FORT-WORTH ELOS
print ('End of tournament elos \n')
showUpdatedElos()
# Out:
# End of tournament elos
#
# HP:
# thieves : 1311.24272551
# gen g : 1285.38653916
# red : 1261.44254521
# optic : 1240.68509701
# denial : 1216.71435296
# splyce : 1211.43390404
# nv : 1200.29489056
# heretics : 1197.5986696
# rec : 1189.47870236
# lg : 1186.05730131
# excel : 1176.82909193
# eunited : 1173.5865983
# eg : 1157.72118953
# e6 : 1148.70457434
# uyu : 1146.49871255
# midnight : 1097.86317061
#
#
# SND:
# rec : 1321.30352211
# lg : 1283.58140956
# thieves : 1277.8766841
# gen g : 1245.22788009
# eunited : 1233.49147174
# splyce : 1225.40978897
# red : 1222.28606565
# optic : 1200.6515438
# heretics : 1188.94997971
# excel : 1187.44769898
# uyu : 1175.82957366
# denial : 1174.74584627
# nv : 1164.31823384
# midnight : 1142.42902261
# e6 : 1125.74067378
# eg : 1037.21974826
#
#
# Control:
# lg : 1338.29399195
# e6 : 1290.64720107
# splyce : 1280.175539
# optic : 1262.18852022
# uyu : 1252.72374718
# nv : 1237.95240524
# red : 1236.13843474
# thieves : 1233.27582346
# ...

# %%
#winChance(uyuHPElo,hereticsHPElo)
#winChance(uyuSNDElo, hereticsSNDElo)
#winChance(uyuCNTRLElo, hereticsCNTRLElo)

# %%
#winChance(redHPElo,excelHPElo)
#winChance(redSNDElo, excelSNDElo)
#winChance(redCNTRLElo, excelCNTRLElo)

# %%
#winChance(nvHPElo,luminHPElo)
#winChance(nvSNDElo, luminSNDElo)
#winChance(nvCNTRLElo, luminCNTRLElo)

# %%
#winChance(egHPElo,eunitedHPElo)
#winChance(egSNDElo, eunitedSNDElo)
#winChance(egCNTRLElo, eunitedCNTRLElo)

# %%
uyuHPElo, hereticsHPElo = EloRating(uyuHPElo, hereticsHPElo)
uyuSNDElo, hereticsSNDElo = EloRating(uyuSNDElo, hereticsSNDElo)
uyuCNTRLElo, hereticsCNTRLElo = EloRating(uyuCNTRLElo, hereticsCNTRLElo)

# %%
excelHPElo, redHPElo = EloRating(excelHPElo, redHPElo)
excelSNDElo, redSNDElo = EloRating(excelSNDElo, redSNDElo)
redCNTRLElo, excelCNTRLElo = EloRating(redCNTRLElo, excelCNTRLElo)
redHPElo, excelHPElo = EloRating(redHPElo, excelHPElo)
redSNDElo, excelSNDElo = EloRating(redSNDElo, excelSNDElo)

# %%
luminHPElo, nvHPElo = EloRating(luminHPElo, nvHPElo)
luminSNDElo, nvSNDElo = EloRating(luminSNDElo, nvSNDElo)
nvCNTRLElo, luminCNTRLElo = EloRating(nvCNTRLElo, luminCNTRLElo)
nvHPElo, luminHPElo = EloRating(nvHPElo, luminHPElo)
nvSNDElo, luminSNDElo = EloRating(nvSNDElo, luminSNDElo)

# %%
eunitedHPElo, egHPElo = EloRating(eunitedHPElo, egHPElo)
egSNDElo, eunitedSNDElo = EloRating(egSNDElo, eunitedSNDElo)
eunitedCNTRLElo, egCNTRLElo = EloRating(eunitedCNTRLElo, egCNTRLElo)
egHPElo, eunitedHPElo = EloRating(egHPElo, eunitedHPElo)
eunitedSNDElo, egSNDElo = EloRating(eunitedSNDElo, egSNDElo)

# %%
print ('End of week 1 day 1 cross-league \n')
showUpdatedElos()
# Out:
# End of week 1 day 1 cross-league
#
# HP:
# thieves : 1311.24272551
# gen g : 1285.38653916
# red : 1254.65446872
# optic : 1240.68509701
# denial : 1216.71435296
# splyce : 1211.43390404
# nv : 1201.04981406
# rec : 1189.47870236
# lg : 1185.30237781
# excel : 1183.61716841
# heretics : 1174.67814801
# eunited : 1169.58799352
# uyu : 1169.41923414
# eg : 1161.71979432
# e6 : 1148.70457434
# midnight : 1097.86317061
#
#
# SND:
# rec : 1321.30352211
# thieves : 1277.8766841
# lg : 1269.02894121
# gen g : 1245.22788009
# splyce : 1225.40978897
# red : 1220.81442403
# eunited : 1215.81671823
# optic : 1200.6515438
# uyu : 1196.58448613
# excel : 1188.9193406
# nv : 1178.8707022
# denial : 1174.74584627
# heretics : 1168.19506724
# midnight : 1142.42902261
# e6 : 1125.74067378
# eg : 1054.89450177
#
#
# Control:
# lg : 1312.67327668
# e6 : 1290.64720107
# splyce : 1280.175539
# uyu : 1267.88344902
# nv : 1263.57312051
# optic : 1262.18852022
# red : 1254.48385158
# ...

# %%
#winChance(hereticsHPElo,egHPElo)
#winChance(hereticsSNDElo, egSNDElo)
#winChance(hereticsCNTRLElo, egCNTRLElo)

# %%
#winChance(eunitedHPElo,uyuHPElo)
#winChance(eunitedSNDElo, uyuSNDElo)
#winChance(eunitedCNTRLElo, uyuCNTRLElo)

# %%
#winChance(luminHPElo,excelHPElo)
#winChance(luminSNDElo, excelSNDElo)
#winChance(luminCNTRLElo, excelCNTRLElo)

# %%
#winChance(redHPElo,nvHPElo)
#winChance(redSNDElo, nvSNDElo)
#winChance(redCNTRLElo, nvCNTRLElo)

# %%
egHPElo, hereticsHPElo = EloRating(egHPElo, hereticsHPElo)
egSNDElo, hereticsSNDElo = EloRating(egSNDElo, hereticsSNDElo)
hereticsCNTRLElo, egCNTRLElo = EloRating(hereticsCNTRLElo, egCNTRLElo)
hereticsHPElo, egHPElo = EloRating(hereticsHPElo, egHPElo)
hereticsSNDElo, egSNDElo = EloRating(hereticsSNDElo, egSNDElo)

# %%
eunitedHPElo, uyuHPElo = EloRating(eunitedHPElo, uyuHPElo)
eunitedSNDElo, uyuSNDElo = EloRating(eunitedSNDElo, uyuSNDElo)
eunitedCNTRLElo, uyuCNTRLElo = EloRating(eunitedCNTRLElo, uyuCNTRLElo)

# %%
luminHPElo, excelHPElo = EloRating(luminHPElo, excelHPElo)
excelSNDElo, luminSNDElo = EloRating(excelSNDElo, luminSNDElo)
luminCNTRLElo, excelCNTRLElo = EloRating(luminCNTRLElo, excelCNTRLElo)
excelHPElo, luminHPElo = EloRating(excelHPElo, luminHPElo)
luminSNDElo, excelSNDElo = EloRating(luminSNDElo, excelSNDElo)

# %%
redHPElo, nvHPElo = EloRating(redHPElo, nvHPElo)
nvSNDElo, redSNDElo = EloRating(nvSNDElo, redSNDElo)
nvCNTRLElo, redCNTRLElo = EloRating(nvCNTRLElo, redCNTRLElo)
redHPElo, nvHPElo = EloRating(redHPElo, nvHPElo)
nvSNDElo, redSNDElo = EloRating(nvSNDElo, redSNDElo)

# %%
print ('End of week 1 day 2 cross-league \n')
showUpdatedElos()
# Out:
# End of week 1 day 2 cross-league
#
# HP:
# thieves : 1311.24272551
# red : 1286.66093124
# gen g : 1285.38653916
# optic : 1240.68509701
# denial : 1216.71435296
# splyce : 1211.43390404
# eunited : 1189.57827895
# rec : 1189.47870236
# excel : 1186.0913115
# lg : 1182.82823473
# heretics : 1175.57135067
# nv : 1169.04335155
# eg : 1160.82659166
# uyu : 1149.42894871
# e6 : 1148.70457434
# midnight : 1097.86317061
#
#
# SND:
# rec : 1321.30352211
# thieves : 1277.8766841
# lg : 1262.7150338
# gen g : 1245.22788009
# eunited : 1234.71075134
# splyce : 1225.40978897
# nv : 1221.10877448
# optic : 1200.6515438
# excel : 1195.23324801
# red : 1178.57635175
# uyu : 1177.69045301
# denial : 1174.74584627
# heretics : 1158.43568597
# midnight : 1142.42902261
# e6 : 1125.74067378
# eg : 1064.65388305
#
#
# Control:
# lg : 1325.83945308
# e6 : 1290.64720107
# nv : 1283.05001946
# splyce : 1280.175539
# optic : 1262.18852022
# uyu : 1240.86574574
# red : 1235.00695263
# ...

# %%
print winChance(redHPElo,hereticsHPElo)
print winChance(redSNDElo, hereticsSNDElo)
print winChance(redCNTRLElo, hereticsCNTRLElo)
# Out:
# chance of team 2 to win: 0.345363410399
# chance of team 2 to win: 0.471047675813
# chance of team 2 to win: 0.402950991862

# %%
print winChance(excelHPElo,uyuHPElo)
print winChance(excelSNDElo, uyuSNDElo)
print winChance(excelCNTRLElo, uyuCNTRLElo)
# Out:
# chance of team 2 to win: 0.447433583995
# chance of team 2 to win: 0.474775321425
# chance of team 2 to win: 0.592532668511

# %%
print winChance(nvHPElo,egHPElo)
print winChance(nvSNDElo, egSNDElo)
print winChance(nvCNTRLElo, egCNTRLElo)
# Out:
# chance of team 2 to win: 0.488177336084
# chance of team 2 to win: 0.288921716712
# chance of team 2 to win: 0.204193839862

# %%
print winChance(luminHPElo,eunitedHPElo)
print winChance(luminSNDElo, eunitedSNDElo)
print winChance(luminCNTRLElo, eunitedCNTRLElo)
# Out:
# chance of team 2 to win: 0.509712872473
# chance of team 2 to win: 0.459785648584
# chance of team 2 to win: 0.286795072925

# %%
hereticsHPElo, redHPElo = EloRating(hereticsHPElo, redHPElo)
hereticsSNDElo, redSNDElo = EloRating(hereticsSNDElo, redSNDElo)
hereticsCNTRLElo, redCNTRLElo = EloRating(hereticsCNTRLElo, redCNTRLElo)

# %%
excelHPElo, uyuHPElo = EloRating(excelHPElo, uyuHPElo)
excelSNDElo, uyuSNDElo = EloRating(excelSNDElo, uyuSNDElo)
excelCNTRLElo, uyuCNTRLElo = EloRating(excelCNTRLElo, uyuCNTRLElo)

# %%
nvHPElo, egHPElo = EloRating(nvHPElo, egHPElo)
egSNDElo, nvSNDElo = EloRating(egSNDElo, nvSNDElo)
egCNTRLElo, nvCNTRLElo = EloRating(egCNTRLElo, nvCNTRLElo)
egHPElo, nvHPElo = EloRating(egHPElo, nvHPElo)

# %%
luminHPElo, eunitedHPElo = EloRating(luminHPElo, eunitedHPElo)
eunitedSNDElo, luminSNDElo = EloRating(eunitedSNDElo, luminSNDElo)
eunitedCNTRLElo, luminCNTRLElo = EloRating(eunitedCNTRLElo, luminCNTRLElo)
luminHPElo, eunitedHPElo = EloRating(luminHPElo, eunitedHPElo)
luminSNDElo, eunitedSNDElo = EloRating(luminSNDElo, eunitedSNDElo)

# %%
print ('End of week 1 day 3 cross-league \n')
showUpdatedElos()
# Out:
# End of week 1 day 3 cross-league
#
# HP:
# thieves : 1311.24272551
# gen g : 1285.38653916
# red : 1260.47546765
# optic : 1240.68509701
# lg : 1221.26423757
# denial : 1216.71435296
# splyce : 1211.43390404
# excel : 1203.98865486
# heretics : 1201.75681425
# rec : 1189.47870236
# nv : 1165.86597785
# eg : 1164.00396536
# eunited : 1151.1422761
# e6 : 1148.70457434
# uyu : 1131.53160535
# midnight : 1097.86317061
#
#
# SND:
# rec : 1321.30352211
# thieves : 1277.8766841
# lg : 1261.98162346
# gen g : 1245.22788009
# eunited : 1235.44416168
# splyce : 1225.40978897
# excel : 1214.22426087
# optic : 1200.6515438
# nv : 1192.66564315
# heretics : 1179.59377894
# denial : 1174.74584627
# uyu : 1158.69944015
# red : 1157.41825878
# midnight : 1142.42902261
# e6 : 1125.74067378
# eg : 1093.09701438
#
#
# Control:
# lg : 1297.311256
# e6 : 1290.64720107
# splyce : 1280.175539
# optic : 1262.18852022
# nv : 1251.21777306
# thieves : 1233.27582346
# uyu : 1217.164439
# red : 1211.1249923
# ...

# %%
print winChance(nvHPElo,uyuHPElo)
print winChance(nvSNDElo, uyuSNDElo)
print winChance(nvCNTRLElo, uyuCNTRLElo)
# Out:
# chance of team 2 to win: 0.450749087298
# chance of team 2 to win: 0.451273839579
# chance of team 2 to win: 0.451149641771

# %%
print winChance(excelHPElo,egHPElo)
print winChance(excelSNDElo, egSNDElo)
print winChance(excelCNTRLElo, egCNTRLElo)
# Out:
# chance of team 2 to win: 0.442710110444
# chance of team 2 to win: 0.332419006554
# chance of team 2 to win: 0.332654607873

# %%
print winChance(redHPElo,eunitedHPElo)
print winChance(redSNDElo, eunitedSNDElo)
print winChance(redCNTRLElo, eunitedCNTRLElo)
# Out:
# chance of team 2 to win: 0.347652848162
# chance of team 2 to win: 0.610437881336
# chance of team 2 to win: 0.478405979916

# %%
print winChance(hereticsHPElo,luminHPElo)
print winChance(hereticsSNDElo, luminSNDElo)
print winChance(hereticsCNTRLElo, luminCNTRLElo)
# Out:
# chance of team 2 to win: 0.528043975747
# chance of team 2 to win: 0.616392148891
# chance of team 2 to win: 0.648934971332

# %%
nvHPElo, uyuHPElo = EloRating(nvHPElo, uyuHPElo)
nvSNDElo, uyuSNDElo = EloRating(nvSNDElo, uyuSNDElo)
nvCNTRLElo, uyuCNTRLElo = EloRating(nvCNTRLElo, uyuCNTRLElo)

# %%
excelHPElo, egHPElo = EloRating(excelHPElo, egHPElo)
excelSNDElo, egSNDElo = EloRating(excelSNDElo, egSNDElo)
excelCNTRLElo, egCNTRLElo = EloRating(excelCNTRLElo, egCNTRLElo)

# %%
eunitedHPElo, redHPElo = EloRating(eunitedHPElo, redHPElo)
redSNDElo, eunitedSNDElo = EloRating(redSNDElo, eunitedSNDElo)
redCNTRLElo, eunitedCNTRLElo = EloRating(redCNTRLElo, eunitedCNTRLElo)
eunitedHPElo, redHPElo = EloRating(eunitedHPElo, redHPElo)
eunitedSNDElo, redSNDElo = EloRating(eunitedSNDElo, redSNDElo)

# %%
hereticsHPElo, luminHPElo = EloRating(hereticsHPElo, luminHPElo)
luminSNDElo, hereticsSNDElo = EloRating(luminSNDElo, hereticsSNDElo)
hereticsCNTRLElo, luminCNTRLElo = EloRating(hereticsCNTRLElo, luminCNTRLElo)
luminHPElo, hereticsHPElo = EloRating(luminHPElo, hereticsHPElo)
hereticsSNDElo, luminSNDElo = EloRating(hereticsSNDElo, luminSNDElo)

# %%
print ('End of week 1 day 4 cross-league \n')
showUpdatedElos()
# Out:
# End of week 1 day 4 cross-league
#
# HP:
# thieves : 1311.24272551
# gen g : 1285.38653916
# optic : 1240.68509701
# excel : 1221.69705927
# lg : 1221.44940831
# denial : 1216.71435296
# splyce : 1211.43390404
# red : 1211.12137331
# heretics : 1201.57164351
# eunited : 1200.49637044
# rec : 1189.47870236
# nv : 1183.89594134
# e6 : 1148.70457434
# eg : 1146.29556094
# uyu : 1113.50164186
# midnight : 1097.86317061
#
#
# SND:
# rec : 1321.30352211
# thieves : 1277.8766841
# lg : 1251.03722289
# gen g : 1245.22788009
# eunited : 1229.35022752
# excel : 1227.52102113
# splyce : 1225.40978897
# nv : 1210.71659673
# optic : 1200.6515438
# heretics : 1190.53817951
# denial : 1174.74584627
# red : 1163.51219294
# midnight : 1142.42902261
# uyu : 1140.64848657
# e6 : 1125.74067378
# eg : 1079.80025412
#
#
# Control:
# e6 : 1290.64720107
# splyce : 1280.175539
# lg : 1271.35385714
# nv : 1269.26375873
# optic : 1262.18852022
# thieves : 1233.27582346
# red : 1230.2612315
# ...

# %%
print winChance(denialHPElo,gengHPElo)
print winChance(denialSNDElo, gengSNDElo)
print winChance(denialCNTRLElo, gengCNTRLElo)
# Out:
# chance of team 2 to win: 0.597560048314
# chance of team 2 to win: 0.600062900643
# chance of team 2 to win: 0.691300094434

# %%
print winChance(midnightHPElo,splyceHPElo)
print winChance(midnightSNDElo, splyceSNDElo)
print winChance(midnightCNTRLElo, splyceCNTRLElo)
# Out:
# chance of team 2 to win: 0.657858550892
# chance of team 2 to win: 0.617198872572
# chance of team 2 to win: 0.74718556946

# %%
print winChance(e6HPElo,opticHPElo)
print winChance(e6SNDElo, opticSNDElo)
print winChance(e6CNTRLElo, opticCNTRLElo)
# Out:
# chance of team 2 to win: 0.629362393753
# chance of team 2 to win: 0.606165345006
# chance of team 2 to win: 0.45913601558

# %%
print winChance(recHPElo,thievesHPElo)
print winChance(recSNDElo, thievesSNDElo)
print winChance(recCNTRLElo, thievesCNTRLElo)
# Out:
# chance of team 2 to win: 0.668393946487
# chance of team 2 to win: 0.437827197371
# chance of team 2 to win: 0.665012012017

# %%
denialHPElo, gengHPElo = EloRating(denialHPElo, gengHPElo)
gengSNDElo, denialSNDElo = EloRating(gengSNDElo, denialSNDElo)
gengCNTRLElo, denialCNTRLElo = EloRating(gengCNTRLElo, denialCNTRLElo)
gengHPElo, denialHPElo = EloRating(gengHPElo, denialHPElo)

# %%
splyceHPElo, midnightHPElo = EloRating(splyceHPElo, midnightHPElo)
splyceSNDElo, midnightSNDElo = EloRating(splyceSNDElo, midnightSNDElo)
midnightCNTRLElo, splyceCNTRLElo = EloRating(midnightCNTRLElo, splyceCNTRLElo)
splyceHPElo, midnightHPElo = EloRating(splyceHPElo, midnightHPElo)

# %%
opticHPElo, e6HPElo = EloRating(opticHPElo, e6HPElo)
e6SNDElo, opticSNDElo = EloRating(e6SNDElo, opticSNDElo)
e6CNTRLElo, opticCNTRLElo = EloRating(e6CNTRLElo, opticCNTRLElo)
opticHPElo, e6HPElo = EloRating(opticHPElo, e6HPElo)
opticSNDElo, e6SNDElo = EloRating(opticSNDElo, e6SNDElo)

# %%
thievesHPElo, recHPElo = EloRating(thievesHPElo, recHPElo)
thievesSNDElo, recSNDElo = EloRating(thievesSNDElo, recSNDElo)
thievesCNTRLElo, recCNTRLElo = EloRating(thievesCNTRLElo, recCNTRLElo)

# %%
print ('End of week 2 day 1 cross-league \n')
showUpdatedElos()
# Out:
# End of week 2 day 1 cross-league
#
# HP:
# thieves : 1324.50696765
# gen g : 1280.28435647
# optic : 1268.78160603
# splyce : 1237.42386812
# denial : 1221.81653565
# excel : 1221.69705927
# lg : 1221.44940831
# red : 1211.12137331
# heretics : 1201.57164351
# eunited : 1200.49637044
# nv : 1183.89594134
# rec : 1176.21446022
# eg : 1146.29556094
# e6 : 1120.60806532
# uyu : 1113.50164186
# midnight : 1071.87320653
#
#
# SND:
# thieves : 1300.3635962
# rec : 1298.81661001
# gen g : 1261.22536407
# lg : 1251.03722289
# splyce : 1240.72183406
# eunited : 1229.35022752
# excel : 1227.52102113
# nv : 1210.71659673
# optic : 1194.88713218
# heretics : 1190.53817951
# red : 1163.51219294
# denial : 1158.7483623
# uyu : 1140.64848657
# e6 : 1131.50508541
# midnight : 1127.11697752
# eg : 1079.80025412
#
#
# Control:
# e6 : 1309.01264169
# lg : 1271.35385714
# nv : 1269.26375873
# splyce : 1250.28811622
# thieves : 1246.67534298
# optic : 1243.8230796
# red : 1230.2612315
# ...

# %%
print winChance(opticHPElo,denialHPElo)
print winChance(opticSNDElo, denialSNDElo)
print winChance(opticCNTRLElo, denialCNTRLElo)
# Out:
# chance of team 2 to win: 0.432820515304
# chance of team 2 to win: 0.448178883795
# chance of team 2 to win: 0.25468053821

# %%
print winChance(recHPElo,e6HPElo)
print winChance(recSNDElo, e6SNDElo)
print winChance(recCNTRLElo, e6CNTRLElo)
# Out:
# chance of team 2 to win: 0.420652317983
# chance of team 2 to win: 0.276253442903
# chance of team 2 to win: 0.768314879096

# %%
print winChance(thievesHPElo,midnightHPElo)
print winChance(thievesSNDElo, midnightSNDElo)
print winChance(thievesCNTRLElo, midnightCNTRLElo)
# Out:
# chance of team 2 to win: 0.189344230103
# chance of team 2 to win: 0.269475025216
# chance of team 2 to win: 0.327664034666

# %%
print winChance(splyceHPElo,gengHPElo)
print winChance(splyceSNDElo, gengSNDElo)
print winChance(splyceCNTRLElo, gengCNTRLElo)
# Out:
# chance of team 2 to win: 0.561370200025
# chance of team 2 to win: 0.529472745203
# chance of team 2 to win: 0.459426223438

# %%
denialHPElo, opticHPElo = EloRating(denialHPElo, opticHPElo)
opticSNDElo, denialSNDElo = EloRating(opticSNDElo, denialSNDElo)
denialCNTRLElo, opticCNTRLElo = EloRating(denialCNTRLElo, opticCNTRLElo)
opticHPElo, denialHPElo = EloRating(opticHPElo, denialHPElo)
opticSNDElo, denialSNDElo = EloRating(opticSNDElo, denialSNDElo)

# %%
recHPElo, e6HPElo = EloRating(recHPElo, e6HPElo)
e6SNDElo, recSNDElo = EloRating(e6SNDElo, recSNDElo)
e6CNTRLElo, recCNTRLElo = EloRating(e6CNTRLElo, recCNTRLElo)
recHPElo, e6HPElo = EloRating(recHPElo, e6HPElo)
recSNDElo, e6SNDElo = EloRating(recSNDElo, e6SNDElo)

# %%
midnightHPElo, thievesHPElo = EloRating(midnightHPElo, thievesHPElo)
midnightSNDElo, thievesSNDElo = EloRating(midnightSNDElo, thievesSNDElo)
thievesCNTRLElo, midnightCNTRLElo = EloRating(thievesCNTRLElo, midnightCNTRLElo)
thievesHPElo, midnightHPElo = EloRating(thievesHPElo, midnightHPElo)
midnightSNDElo, thievesSNDElo = EloRating(midnightSNDElo, thievesSNDElo)

# %%
gengHPElo, splyceHPElo = EloRating(gengHPElo, splyceHPElo)
gengSNDElo, splyceSNDElo = EloRating(gengSNDElo, splyceSNDElo)
splyceCNTRLElo, gengCNTRLElo = EloRating(splyceCNTRLElo, gengCNTRLElo)
gengHPElo, splyceHPElo = EloRating(gengHPElo, splyceHPElo)

# %%
print ('End of week 2 day 2 cross-league \n')
showUpdatedElos()
# Out:
# End of week 2 day 2 cross-league
#
# HP:
# gen g : 1313.41614181
# thieves : 1302.21374226
# optic : 1266.00285856
# denial : 1224.59528312
# excel : 1221.69705927
# lg : 1221.44940831
# red : 1211.12137331
# rec : 1208.01255029
# splyce : 1204.29208278
# heretics : 1201.57164351
# eunited : 1200.49637044
# nv : 1183.89594134
# eg : 1146.29556094
# uyu : 1113.50164186
# midnight : 1094.16643192
# e6 : 1088.80997525
#
#
# SND:
# rec : 1283.76875697
# gen g : 1280.04645426
# lg : 1251.03722289
# thieves : 1244.76437871
# eunited : 1229.35022752
# optic : 1228.72834549
# excel : 1227.52102113
# splyce : 1221.90074387
# nv : 1210.71659673
# heretics : 1190.53817951
# midnight : 1182.71619501
# red : 1163.51219294
# e6 : 1146.55293845
# uyu : 1140.64848657
# denial : 1124.90714899
# eg : 1079.80025412
#
#
# Control:
# e6 : 1318.28004653
# lg : 1271.35385714
# nv : 1269.26375873
# splyce : 1268.66516516
# thieves : 1259.78190436
# red : 1230.2612315
# heretics : 1216.54321098
# ...

# %%
midnightHPElo, e6HPElo = EloRating(midnightHPElo, e6HPElo)
midnightSNDElo, e6SNDElo = EloRating(midnightSNDElo, e6SNDElo)
e6CNTRLElo, midnightCNTRLElo = EloRating(e6CNTRLElo, midnightCNTRLElo)
midnightHPElo, e6HPElo = EloRating(midnightHPElo, e6HPElo)

# %%
recHPElo, denialHPElo = EloRating(recHPElo, denialHPElo)
denialSNDElo, recSNDElo = EloRating(denialSNDElo, recSNDElo)
recCNTRLElo, denialCNTRLElo = EloRating(recCNTRLElo, denialCNTRLElo)
recHPElo, denialHPElo = EloRating(recHPElo, denialHPElo)

# %%
thievesHPElo, gengHPElo = EloRating(thievesHPElo, gengHPElo)
gengSNDElo, thievesSNDElo = EloRating(gengSNDElo, thievesSNDElo)
thievesCNTRLElo, gengCNTRLElo = EloRating(thievesCNTRLElo, gengCNTRLElo)
thievesHPElo, gengHPElo = EloRating(thievesHPElo, gengHPElo)

# %%
opticHPElo, splyceHPElo = EloRating(opticHPElo, splyceHPElo)
opticSNDElo, splyceSNDElo = EloRating(opticSNDElo, splyceSNDElo)
splycelCNTRLElo, opticCNTRLElo = EloRating(splyceCNTRLElo, opticCNTRLElo)
splyceHPElo, opticHPElo = EloRating(splyceHPElo, opticHPElo)
opticSNDElo, splyceSNDElo = EloRating(opticSNDElo, splyceSNDElo)

# %%
print ('End of week 2 day 3 cross-league \n')
showUpdatedElos()
# Out:
# End of week 2 day 3 cross-league
#
# HP:
# thieves : 1341.13075729
# gen g : 1274.49912678
# optic : 1257.16820593
# rec : 1247.51115848
# excel : 1221.69705927
# lg : 1221.44940831
# splyce : 1213.12673541
# red : 1211.12137331
# heretics : 1201.57164351
# eunited : 1200.49637044
# denial : 1185.09667493
# nv : 1183.89594134
# eg : 1146.29556094
# midnight : 1131.29682438
# uyu : 1113.50164186
# e6 : 1051.67958278
#
#
# SND:
# gen g : 1298.02240754
# optic : 1265.70040384
# rec : 1255.21210805
# lg : 1251.03722289
# eunited : 1229.35022752
# excel : 1227.52102113
# thieves : 1226.78842542
# nv : 1210.71659673
# midnight : 1200.64195595
# heretics : 1190.53817951
# splyce : 1184.92868552
# red : 1163.51219294
# denial : 1153.46379791
# uyu : 1140.64848657
# e6 : 1128.62717751
# eg : 1079.80025412
#
#
# Control:
# e6 : 1327.49354566
# thieves : 1276.57881757
# lg : 1271.35385714
# nv : 1269.26375873
# splyce : 1268.66516516
# red : 1230.2612315
# heretics : 1216.54321098
# ...

# %%
gengHPElo, e6HPElo = EloRating(gengHPElo, e6HPElo)
e6SNDElo, gengSNDElo = EloRating(e6SNDElo, gengSNDElo)
gengCNTRLElo, e6CNTRLElo = EloRating(gengCNTRLElo, e6CNTRLElo)
gengHPElo, e6HPElo = EloRating(gengHPElo, e6HPElo)

# %%
midnightHPElo, denialHPElo = EloRating(midnightHPElo, denialHPElo)
denialSNDElo, midnightSNDElo = EloRating(denialSNDElo, midnightSNDElo)
midnightCNTRLElo, denialCNTRLElo = EloRating(midnightCNTRLElo, denialCNTRLElo)
denialHPElo, midnightHPElo = EloRating(denialHPElo, midnightHPElo)
denialSNDElo, midnightSNDElo = EloRating(denialSNDElo, midnightSNDElo)

# %%
recHPElo, splyceHPElo = EloRating(recHPElo, splyceHPElo)
splyceSNDElo, recSNDElo = EloRating(splyceSNDElo, recSNDElo)
splycelCNTRLElo, recCNTRLElo = EloRating(splyceCNTRLElo, recCNTRLElo)
splyceHPElo, recHPElo = EloRating(splyceHPElo, recHPElo)

# %%
thievesHPElo, opticHPElo = EloRating(thievesHPElo, opticHPElo)
thievesSNDElo, opticSNDElo = EloRating(thievesSNDElo, opticSNDElo)
thievesCNTRLElo, opticCNTRLElo = EloRating(thievesCNTRLElo, opticCNTRLElo)

# %%
#POST CROSS-LEAGUE ELOS
print ('End of cross-league \n')
showUpdatedElos()
# Out:
# End of cross-league
#
# HP:
# thieves : 1356.38942692
# gen g : 1291.20656567
# optic : 1241.9095363
# rec : 1241.53815056
# excel : 1221.69705927
# lg : 1221.44940831
# splyce : 1219.09974334
# red : 1211.12137331
# heretics : 1201.57164351
# eunited : 1200.49637044
# nv : 1183.89594134
# denial : 1181.58364148
# eg : 1146.29556094
# midnight : 1134.80985783
# uyu : 1113.50164186
# e6 : 1034.97214389
#
#
# SND:
# gen g : 1268.97687498
# lg : 1251.03722289
# thieves : 1249.01906011
# optic : 1243.46976916
# rec : 1231.22056837
# eunited : 1229.35022752
# excel : 1227.52102113
# nv : 1210.71659673
# splyce : 1208.9202252
# denial : 1196.26546871
# heretics : 1190.53817951
# red : 1163.51219294
# midnight : 1157.84028514
# e6 : 1157.67271007
# uyu : 1140.64848657
# eg : 1079.80025412
#
#
# Control:
# e6 : 1299.81291171
# thieves : 1292.08350286
# lg : 1271.35385714
# nv : 1269.26375873
# splyce : 1268.66516516
# red : 1230.2612315
# heretics : 1216.54321098
# gen g : 1214.5391106
# ...
